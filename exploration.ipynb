# %%
# TODO: create a higher level function that will iterate with parse_dictionary_main_page 
#       and scrape the WHOLE dictionary (A - Z)
# TODO: descriptions longer than 300 char cause an error

# %%
import pandas as pd
import requests
import pickle
import re
import random
import praw
import time
from bs4 import BeautifulSoup

# %%
from utils import *

# %%
creds = pickle.load(open('creds', 'rb'))

# %%
def parse_entire_dictionary():
    stem = 'https://lifeprint.com/asl101/index/'
    full_dict = {}
    for letter in 'abcdefghijklmnopqrstuvwxyz': #
        letter_dict = parse_dictionary_main_page(stem + letter + '.htm')
        full_dict.update(letter_dict)
        time.sleep(0.5)
    return full_dict

def parse_dictionary_main_page(url):
    '''
    The dictionary main page contains links to subpages with words.
    Takes a url (ex. https://lifeprint.com/asl101/index/a.htm)
    Returns a dictionary with the dictionary entry as the key,
    and the link to the dictionary content page as the value
    '''
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    links_html = soup.find_all("a", href = True)
    links_html = [link for link in links_html if len(link.parent) > 1]
    master_dict = {}
    for blob in links_html:
        text = blob.text
        link = blob.get("href")
        link = re.sub('\.\.', 'https://lifeprint.com/asl101/', link)
        master_dict[text] = link
    return(master_dict)

def parse_dictionary_content_page(url, name):
    '''
    The content page contains images and videos describing the word
    Takes a url (ex. https://lifeprint.com/asl101//pages-signs/a/active.htm)
    Returns a pandas dataframe as follows:
    # pandas df:
    # name
    # type ("image", "gif", or "video")
    # text
    # location (the web address where the content can be found)
    '''
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    videos = soup.find_all('iframe')
    df = pd.DataFrame()
    for video in videos:
        row = {}
        row['name'] = name
        row['type'] = 'youtube'
        row['text'] = get_description(video)
        row['location'] = video['src']
        df = df.append(row, ignore_index=True)
    return(df)

# %%
def get_description(element):
    text_array = []
    temp = element
    while True:
        temp = temp.previous
        if temp.name == 'hr' or temp.name == 'font':
            break 
        if isinstance(temp, type('bs4.element.NavigableString')):
            text_array.append(temp)
    # reverse text_array, then
    text_array.reverse()
    description = ''.join(text_array)
    # Clean for Reddit Title 
    description = re.sub('(\n|\t)+', '', description)
    description = smart_truncate(description)
    return(description)

def smart_truncate(content, length=300, suffix='...'):
    # from https://stackoverflow.com/questions/250357/truncate-a-string-without-ending-in-the-middle-of-a-word
    if len(content) <= length:
        return content
    else:
        return ' '.join(content[:length+1].split(' ')[0:-1]) + suffix

# %%
def post_random_content(main_page, reddit_creds, content_type = 'random'):
    if content_type == 'random':
        content_type = random.choice(['image', 'youtube', 'mp4'])
    content_df = pd.DataFrame
    i = 0
    while True:
        name = random.choice([*main_page.keys()])
        url = main_page[name]
        content_df = parse_dictionary_content_page(url, name)
        i += 1
        if i > 100 or not content_df.empty:
            break
    chosen_row = content_df.iloc[random.choice(content_df.index)]
    if content_type == 'image':
        pass
    elif content_type == 'youtube':
        post_youtube(chosen_row, reddit_creds)
    elif content_type == 'mp4':
        pass
    return chosen_row

def post_youtube(df_row, reddit_creds):
    title = df_row['name'] + ' | ' + df_row['text']
    url = df_row['location']
    reddit = praw.Reddit(
        user_agent="test",
        client_id=creds['CLIENT_ID'],
        client_secret=creds['CLIENT_SECRET'],
        username=creds['USERNAME'],
        password=creds['PASSWORD'])
    reddit.validate_on_submit = True
    reddit.subreddit("u_hands---free").submit(title=title, url=url)
    print('YouTube embedded video posted to Reddit')

# %%
entire_dict = parse_entire_dictionary()
entire_dict
# Out:
# {'@': 'https://lifeprint.com/asl101//pages-signs/a/at.htm',
#  "ABC's": 'https://lifeprint.com/asl101//pages-signs/a/abcs.htm',
#  'ABBREVIATE': 'https://lifeprint.com/asl101//pages-signs/a/abbreviate.htm',
#  'ABORTION': 'https://lifeprint.com/asl101//pages-signs/a/abortion.htm',
#  'ABOUT': 'https://lifeprint.com/asl101//pages-signs/a/about.htm',
#  'ABOVE': 'https://lifeprint.com/asl101//pages-signs/a/above.htm',
#  'ABUSE': 'https://lifeprint.com/asl101//pages-signs/a/abuse.htm',
#  'ACADEMIC': 'https://lifeprint.com/asl101//pages-signs/a/academic.htm',
#  'ACCEPT': 'https://lifeprint.com/asl101//pages-signs/a/accept.htm',
#  'ACCENT': 'https://lifeprint.com/asl101//pages-signs/a/accent.htm',
#  'ACCIDENT': 'https://lifeprint.com/asl101//pages-signs/a/accident.htm',
#  'accompany-[see WITH]': 'https://lifeprint.com/asl101//pages-signs/w/with.htm',
#  'ACCOMPLICE': 'https://lifeprint.com/asl101//pages-signs/a/accomplice.ht.htm',
#  'ACCOMPLISH': 'https://lifeprint.com/asl101//pages-signs/a/accomplish.htm',
#  'ACCOUNTANT': 'https://lifeprint.com/asl101//pages-signs/c/count.htm',
#  'ACQUAINTANCE': 'https://lifeprint.com/asl101//pages-signs/a/acquaintance.htm',
#  'ACQUIRE': 'https://lifeprint.com/asl101//pages-signs/a/acquire.htm',
#  'ACROSS': 'https://lifeprint.com/asl101//pages-signs/a/across.htm',
#  'ACT': 'https://lifeprint.com/asl101//pages-signs/a/act.htm',
#  'ACTIVE': 'https://lifeprint.com/asl101//pages-signs/a/active.htm',
#  'ACTOR': 'https://lifeprint.com/asl101//pages-signs/a/actor.htm',
#  'ACTUALLY': 'https://lifeprint.com/asl101//pages-signs/a/actually.htm',
#  'ADD': 'https://lifeprint.com/asl101//pages-signs/a/add.htm',
#  'ADDICT': 'https://lifeprint.com/asl101//pages-signs/a/addict.htm',
#  'add-to': 'https://lifeprint.com/asl101//pages-signs/a/all-together.htm',
#  'ADDRESS': 'https://lifeprint.com/asl101//pages-signs/a/address.htm',
#  'administration-[see MANAGER]': 'https://lifeprint.com/asl101//pages-signs/m/manager.htm',
#  'adopt-[see TAKE-UP]': 'https://lifeprint.com/asl101//pages-signs/t/take-up.htm',
#  'ADOPT': 'https://lifeprint.com/asl101//pages-signs/a/adopt.htm',
#  'ADULT': 'https://lifeprint.com/asl101//pages-signs/a/adult.htm',
#  'advise/advice-[see COUNSEL]': 'https://lifeprint.com/asl101//pages-signs/c/counsel.htm',
#  'AFRAID': 'https://lifeprint.com/asl101//pages-signs/a/afraid.htm',
#  'AFRICA': 'https://lifeprint.com/asl101//pages-signs/a/africa.htm',
#  'AFTER': 'https://lifeprint.com/asl101//pages-signs/a/after.htm',
#  'AFTERNOON': 'https://lifeprint.com/asl101//pages-signs/a/afternoon.htm',
#  'AGAIN': 'https://lifeprint.com/asl101//pages-signs/a/again.htm',
#  'AGAINST': 'https://lifeprint.com/asl101//pages-signs/a/against.htm',
#  'AGENT': 'https://lifeprint.com/asl101//pages-signs/a/agent.htm',
#  'AGGRESSIVE': 'https://lifeprint.com/asl101//pages-signs/a/aggressive.htm',
#  'AGREE': 'https://lifeprint.com/asl101//pages-signs/a/agree.htm',
#  'AIDE': 'https://lifeprint.com/asl101//pages-signs/a/aide.htm',
#  'AIR': 'https://lifeprint.com/asl101//pages-signs/a/air.htm',
#  'AIR CONDITIONING': 'https://lifeprint.com/asl101//pages-signs/a/air-conditioning.htm',
#  'AIRPLANE': 'https://lifeprint.com/asl101//pages-signs/a/airplane.htm',
#  'ALABAMA': 'https://lifeprint.com/asl101//pages-signs/a/alabama.htm',
#  'ALASKA': 'https://lifeprint.com/asl101//pages-signs/a/alaska.htm',
#  'ALCOHOL': 'https://lifeprint.com/asl101//pages-signs/a/alcohol.htm',
#  'ALCOHOLIC': 'https://lifeprint.com/asl101//pages-signs/a/alcoholic.htm',
#  'allergy': 'https://lifeprint.com/asl101//pages-signs/o/opposite.htm',
#  'ALL': 'https://lifeprint.com/asl101//pages-signs/a/all.htm',
#  'ALLIGATOR': 'https://lifeprint.com/asl101//pages-signs/a/alligator.htm',
#  'all-over/-dom-[see FIELD]': 'https://lifeprint.com/asl101//pages-signs/f/field.htm',
#  'ALLOW': 'https://lifeprint.com/asl101//pages-signs/a/allow.htm',
#  'almost-[see EASY]': 'https://lifeprint.com/asl101//pages-signs/a/almost.htm',
#  'alone-[see SINGLE]': 'https://lifeprint.com/asl101//pages-signs/s/single.htm',
#  'A-LOT': 'https://lifeprint.com/asl101//pages-signs/a/a-lot.htm',
#  'ALMOST': 'https://lifeprint.com/asl101//pages-signs/a/almost.htm',
#  'ALOHA': 'https://lifeprint.com/asl101//pages-signs/a/aloha.htm',
#  'ALPHABET': 'https://lifeprint.com/asl101//pages-signs/a/alphabet.htm',
#  'ALRIGHT': 'https://lifeprint.com/asl101//pages-signs/a/alright.htm',
#  'ALSO': 'https://lifeprint.com/asl101//pages-signs/a/also.htm',
#  'ALTOGETHER': 'https://lifeprint.com/asl101//pages-signs/a/altogether.htm',
#  'ALWAYS': 'https://lifeprint.com/asl101//pages-signs/a/always.htm',
#  'AM': 'https://lifeprint.com/asl101//pages-signs/a/am.htm',
#  'ambulance-[see LIGHT]': 'https://lifeprint.com/asl101//pages-signs/l/light.htm',
#  'AMERICA': 'https://lifeprint.com/asl101//pages-signs/a/america.htm',
#  'American': 'https://lifeprint.com/asl101//pages-signs/a/american.htm',
#  'American: Native American': 'https://lifeprint.com/asl101//pages-signs/a/american-indian.htm',
#  'Amish': 'https://lifeprint.com/asl101//pages-signs/a/amish.htm',
#  'AMOUNT': 'https://lifeprint.com/asl101//pages-signs/a/amount.htm',
#  'an': 'https://lifeprint.com/asl101//pages-signs/a/an.htm',
#  'AND': 'https://lifeprint.com/asl101//pages-signs/a/and.htm',
#  'ANGEL': 'https://lifeprint.com/asl101//pages-signs/a/angel.htm',
#  'ANGRY': 'https://lifeprint.com/asl101//pages-signs/a/angry.htm',
#  'ANIMAL': 'https://lifeprint.com/asl101//pages-signs/a/animal.htm',
#  'ANIMALS': 'https://lifeprint.com/asl101//pages-signs/a/animals.htm',
#  'annually': 'https://lifeprint.com/asl101//pages-signs/y/yearadvanced.htm',
#  'ANSWER': 'https://lifeprint.com/asl101//pages-signs/a/answer.htm',
#  'ANT': 'https://lifeprint.com/asl101//pages-signs/a/ant.htm',
#  'ANTHROPOLOGY': 'https://lifeprint.com/asl101//pages-signs/a/anthropology.htm',
#  'ANY': 'https://lifeprint.com/asl101//pages-signs/a/any.htm',
#  'ANXIOUS': 'https://lifeprint.com/asl101//pages-signs/a/anxious.htm',
#  'APARTMENT': 'https://lifeprint.com/asl101//pages-signs/a/apartment.htm',
#  'APE': 'https://lifeprint.com/asl101//pages-signs/a/ape.htm',
#  'APOSTROPHE': 'https://lifeprint.com/asl101//pages-signs/a/apostrophe.htm',
#  'APOSTROPHE S': 'https://lifeprint.com/asl101//pages-signs/a/apostrophe-s.htm',
#  'APPEAR': 'https://lifeprint.com/asl101//pages-signs/a/appear.htm',
#  'APPLAUSE': 'https://lifeprint.com/asl101//pages-signs/a/applause.htm',
#  'APPLE': 'https://lifeprint.com/asl101//pages-signs/a/apple.htm',
#  'APPLY': 'https://lifeprint.com/asl101//pages-signs/a/apply.htm',
#  'APPOINTMENT': 'https://lifeprint.com/asl101//pages-signs/a/appointment.htm',
#  'APPRECIATE': 'https://lifeprint.com/asl101//pages-signs/e/enjoy.htm',
#  'APPROXIMATELY': 'https://lifeprint.com/asl101//pages-signs/a/approximately.htm',
#  'ARE': 'https://lifeprint.com/asl101//pages-signs/a/are.htm',
#  'AREA': 'https://lifeprint.com/asl101//pages-signs/a/area.htm',
#  'ARGUE': 'https://lifeprint.com/asl101//pages-signs/a/argue.htm',
#  'ARIZONA': 'https://lifeprint.com/asl101//pages-signs/a/arizona.htm',
#  'ARKANSAS': 'https://lifeprint.com/asl101//pages-signs/a/arkansas.htm',
#  'ARMY': 'https://lifeprint.com/asl101//pages-signs/a/army.htm',
#  '\naround-[see APPROXIMATELY]': 'https://lifeprint.com/asl101//pages-signs/a/approximately.htm',
#  'ARRIVE': 'https://lifeprint.com/asl101//pages-signs/a/arrive.htm',
#  'art-[see DRAW]': 'https://lifeprint.com/asl101//pages-signs/d/draw.htm',
#  'ARTHRITIS': 'https://lifeprint.com/asl101//pages-signs/a/arthritis.htm',
#  '\narticle/column-[see CL:C]': 'https://lifeprint.com/asl101//pages-signs/c/clc.htm',
#  'ARTICLE': 'https://lifeprint.com/asl101//pages-signs/a/article.htm',
#  'ASK': 'https://lifeprint.com/asl101//pages-signs/a/ask.htm',
#  'ASSAULT': 'https://lifeprint.com/asl101//pages-signs/a/assault.htm',
#  '\nASSIGNMENT': 'https://lifeprint.com/asl101//pages-signs/a/assignment.htm',
#  'ASSOCIATE': 'https://lifeprint.com/asl101//pages-signs/a/associate.htm',
#  'ASSOCIATION': 'https://lifeprint.com/asl101//pages-signs/a/association.htm',
#  'ASTERISK': 'https://lifeprint.com/asl101//pages-signs/a/asterisk.htm',
#  '\nAT': 'https://lifeprint.com/asl101//pages-signs/a/at.htm',
#  'ATM': 'https://lifeprint.com/asl101//pages-signs/a/atm.htm',
#  'ATLANTA': 'https://lifeprint.com/asl101//pages-signs/a/atlanta.htm',
#  'ATTENTION': 'https://lifeprint.com/asl101//pages-signs/a/attention.htm',
#  'AUDIENCE': 'https://lifeprint.com/asl101//pages-signs/a/audience.htm',
#  'AUNT': 'https://lifeprint.com/asl101//pages-signs/a/aunt.htm',
#  'AUSTRALIA': 'https://lifeprint.com/asl101//pages-signs/a/australia.htm',
#  'AUTISM': 'https://lifeprint.com/asl101//pages-signs/a/autism.htm',
#  'AUTUMN': 'https://lifeprint.com/asl101//pages-signs/a/autumn.htm',
#  'AVERAGE': 'https://lifeprint.com/asl101//pages-signs/a/average.htm',
#  'AVOCADO': 'https://lifeprint.com/asl101//pages-signs/a/avocado.htm',
#  '\nAWAY': 'https://lifeprint.com/asl101//pages-signs/a/away.htm',
#  'AWESOME': 'https://lifeprint.com/asl101//pages-signs/a/awesome.htm',
#  'AWFUL': 'https://lifeprint.com/asl101//pages-signs/a/awful.htm',
#  'AWKWARD': 'https://lifeprint.com/asl101//pages-signs/a/awkward.htm',
#  'BABY': 'https://lifeprint.com/asl101//pages-signs/b/baby.htm',
#  'BABYSITTER': 'https://lifeprint.com/asl101//pages-signs/b/babysitter.htm',
#  'BACHELOR': 'https://lifeprint.com/asl101//pages-signs/b/bachelor.htm',
#  'BACK': 'https://lifeprint.com/asl101//pages-signs/b/back.htm',
#  'BACKPACK': 'https://lifeprint.com/asl101//pages-signs/b/backpack.htm',
#  'BACK-STAB': 'https://lifeprint.com/asl101//pages-signs/b/back-stab.htm',
#  'BAD': 'https://lifeprint.com/asl101//pages-signs/b/bad.htm',
#  'BAG': 'https://lifeprint.com/asl101//pages-signs/b/bag.htm',
#  'BAIL': 'https://lifeprint.com/asl101//pages-signs/b/bail.htm',
#  'BAKE': 'https://lifeprint.com/asl101//pages-signs/b/bake.htm',
#  'BALD': 'https://lifeprint.com/asl101//pages-signs/b/bald.htm',
#  'BALL': 'https://lifeprint.com/asl101//pages-signs/b/ball.htm',
#  'BALLOON': 'https://lifeprint.com/asl101//pages-signs/b/balloon.htm',
#  'BALTIMORE': 'https://lifeprint.com/asl101//pages-signs/b/baltimore.htm',
#  'BANANA': 'https://lifeprint.com/asl101//pages-signs/b/banana.htm',
#  'BANDAGE': 'https://lifeprint.com/asl101//pages-signs/b/bandage.htm',
#  'BANGLADESH': 'https://lifeprint.com/asl101//pages-signs/b/bangladesh.htm',
#  'BANK-[#BANK-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/b/bank.htm',
#  'BAPTIZE': 'https://lifeprint.com/asl101//pages-signs/b/baptize.htm',
#  'BARBER': 'https://lifeprint.com/asl101//pages-signs/b/barber.htm',
#  'BASEBALL': 'https://lifeprint.com/asl101//pages-signs/b/baseball.htm',
#  'BASEMENT': 'https://lifeprint.com/asl101//pages-signs/b/basement.htm',
#  'BASKET': 'https://lifeprint.com/asl101//pages-signs/b/basket.htm',
#  'BASKETBALL': 'https://lifeprint.com/asl101//pages-signs/b/basketball.htm',
#  'BASSOON': 'https://lifeprint.com/asl101//pages-signs/b/bassoon.htm',
#  '\nBAT': 'https://lifeprint.com/asl101//pages-signs/b/bat.htm',
#  'BATHROOM': 'https://lifeprint.com/asl101//pages-signs/b/bathroom.htm',
#  'BATHTUB': 'https://lifeprint.com/asl101//pages-signs/b/bathtub.htm',
#  'BATTERY': 'https://lifeprint.com/asl101//pages-signs/b/battery.htm',
#  'be-[ "be verbs"]': 'https://lifeprint.com/asl101//pages-signs/b/be-verbs.htm',
#  'BEACH': 'https://lifeprint.com/asl101//pages-signs/b/beach.htm',
#  'BEAR': 'https://lifeprint.com/asl101//pages-signs/b/bear.htm',
#  'BEARD': 'https://lifeprint.com/asl101//pages-signs/b/beard.htm',
#  'BEAUTIFUL': 'https://lifeprint.com/asl101//pages-signs/b/beautiful.htm',
#  'BECOME': 'https://lifeprint.com/asl101//pages-signs/b/become.htm',
#  'because': 'https://lifeprint.com/asl101//pages-signs/b/because.htm',
#  'bed': 'https://lifeprint.com/asl101//pages-signs/b/bed.htm',
#  'bed-"go make your bed"': 'https://lifeprint.com/asl101//pages-signs/b/bed-make.htm',
#  'BEDROOM': 'https://lifeprint.com/asl101//pages-signs/b/bedroom.htm',
#  'BEE': 'https://lifeprint.com/asl101//pages-signs/b/bee.htm',
#  'BEEF': 'https://lifeprint.com/asl101//pages-signs/b/beef.htm',
#  'been': 'https://lifeprint.com/asl101//pages-signs/b/been.htm',
#  'BEER': 'https://lifeprint.com/asl101//pages-signs/b/beer.htm',
#  'BEFORE': 'https://lifeprint.com/asl101//pages-signs/b/before.htm',
#  'begin / start': 'https://lifeprint.com/asl101//pages-signs/b/begin.htm',
#  'BEHAVE': 'https://lifeprint.com/asl101//pages-signs/b/behave.htm',
#  'BEHAVIOR': 'https://lifeprint.com/asl101//pages-signs/b/behavior.htm',
#  'behind-[see WITH]': 'https://lifeprint.com/asl101//pages-signs/w/with.htm',
#  'BELIEVE': 'https://lifeprint.com/asl101//pages-signs/b/believe.htm',
#  'BELL': 'https://lifeprint.com/asl101//pages-signs/b/bell.htm',
#  '\nBELLYBUTTON': 'https://lifeprint.com/asl101//pages-signs/b/bellybutton.htm',
#  'below': 'https://lifeprint.com/asl101//pages-signs/b/below.htm',
#  'BELT\n': 'https://lifeprint.com/asl101//pages-signs/b/belt.htm',
#  'BENCH': 'https://lifeprint.com/asl101//pages-signs/b/bench.htm',
#  'beneath-[see below]': 'https://lifeprint.com/asl101//pages-signs/b/below.htm',
#  'BERRY': 'https://lifeprint.com/asl101//pages-signs/b/berry.htm',
#  'BEST': 'https://lifeprint.com/asl101//pages-signs/b/best.htm',
#  'BETTER': 'https://lifeprint.com/asl101//pages-signs/b/better.htm',
#  'between': 'https://lifeprint.com/asl101//pages-signs/b/between.htm',
#  'BICEPS': 'https://lifeprint.com/asl101//pages-signs/b/bicep.htm',
#  'BICYCLE': 'https://lifeprint.com/asl101//pages-signs/b/bicycle.htm',
#  'BIG': 'https://lifeprint.com/asl101//pages-signs/b/big.htm',
#  '\nBIG-DIPPER': 'https://lifeprint.com/asl101//pages-signs/b/big-dipper.htm',
#  'BIKINI': 'https://lifeprint.com/asl101//pages-signs/b/bikini.htm',
#  '\nBINOCULARS': 'https://lifeprint.com/asl101//pages-signs/b/binoculars.htm',
#  'BIRD': 'https://lifeprint.com/asl101//pages-signs/b/bird.htm',
#  'BIRTH': 'https://lifeprint.com/asl101//pages-signs/b/birth.htm',
#  'BIRTHDAY': 'https://lifeprint.com/asl101//pages-signs/b/birthday.htm',
#  'BITE': 'https://lifeprint.com/asl101//pages-signs/b/bite.htm',
#  'BLACK': 'https://lifeprint.com/asl101//pages-signs/b/black.htm',
#  '\nBLACKBOARD': 'https://lifeprint.com/asl101//pages-signs/b/blackboard.htm',
#  'BLAME': 'https://lifeprint.com/asl101//pages-signs/b/blame.htm',
#  'BLANKET': 'https://lifeprint.com/asl101//pages-signs/b/blanket.htm',
#  'BLOCK': 'https://lifeprint.com/asl101//pages-signs/b/block.htm',
#  'BLOOD': 'https://lifeprint.com/asl101//pages-signs/b/blood.htm',
#  '"draw-blood"': 'https://lifeprint.com/asl101//pages-signs/b/blood-draw.htm',
#  'SHIRT': 'https://lifeprint.com/asl101//pages-signs/s/shirt.htm',
#  'BLOW-DRY': 'https://lifeprint.com/asl101//pages-signs/b/blow-dry.htm',
#  'BLUE': 'https://lifeprint.com/asl101//pages-signs/b/blue.htm',
#  'BLUE-RAY ': 'https://lifeprint.com/asl101//pages-signs/b/blue-ray.htm',
#  'BLURT': 'https://lifeprint.com/asl101//pages-signs/b/blurt.htm',
#  'BO STAFF': 'https://lifeprint.com/asl101//pages-signs/b/bo-staff.htm',
#  'BOAT': 'https://lifeprint.com/asl101//pages-signs/b/boat.htm',
#  'BODY': 'https://lifeprint.com/asl101//pages-signs/b/body.htm',
#  'body-parts': 'https://lifeprint.com/asl101//pages-signs/b/body-parts.htm',
#  'BOIL': 'https://lifeprint.com/asl101//pages-signs/b/boil.htm',
#  'BOLD': 'https://lifeprint.com/asl101//pages-signs/b/bold.htm',
#  'BOLOGNA': 'https://lifeprint.com/asl101//pages-signs/b/bologna.htm',
#  'BOOK': 'https://lifeprint.com/asl101//pages-signs/b/book.htm',
#  'BOOKSTORE': 'https://lifeprint.com/asl101//pages-signs/b/bookstore.htm',
#  'boots': 'https://lifeprint.com/asl101//pages-signs/b/boots.htm',
#  'BOUQUET': 'https://lifeprint.com/asl101//pages-signs/b/bouquet.htm',
#  'BORED': 'https://lifeprint.com/asl101//pages-signs/b/bored.htm',
#  'born': 'https://lifeprint.com/asl101//pages-signs/b/birth.htm',
#  'LOAN': 'https://lifeprint.com/asl101//pages-signs/l/loan.htm',
#  'BOSS': 'https://lifeprint.com/asl101//pages-signs/b/boss.htm',
#  'BOSTON': 'https://lifeprint.com/asl101//pages-signs/b/boston.htm',
#  'both': 'https://lifeprint.com/asl101//pages-signs/b/both.htm',
#  'bother': 'https://lifeprint.com/asl101//pages-signs/b/bother.htm',
#  'CUP': 'https://lifeprint.com/asl101//pages-signs/c/cup.htm',
#  'bottom': 'https://lifeprint.com/asl101//pages-signs/b/below.htm',
#  'BOWEL \nMOVEMENT': 'https://lifeprint.com/asl101//pages-signs/b/bowelmovement.htm',
#  'BOWL': 'https://lifeprint.com/asl101//pages-signs/b/bowl.htm',
#  'BOWLING': 'https://lifeprint.com/asl101//pages-signs/b/bowling.htm',
#  'bow-tie': 'https://lifeprint.com/asl101//pages-signs/b/bow-tie.htm',
#  'BOX': 'https://lifeprint.com/asl101//pages-signs/b/box.htm',
#  'BOY': 'https://lifeprint.com/asl101//pages-signs/b/boy.htm',
#  'BOYFRIEND': 'https://lifeprint.com/asl101//pages-signs/b/boyfriend.htm',
#  'bracelet': 'https://lifeprint.com/asl101//pages-signs/b/bracelet.htm',
#  'BRA': 'https://lifeprint.com/asl101//pages-signs/b/bra.htm',
#  'BRAIN': 'https://lifeprint.com/asl101//pages-signs/b/brain.htm',
#  'BRANCH': 'https://lifeprint.com/asl101//pages-signs/b/branch.htm',
#  'BRAVE': 'https://lifeprint.com/asl101//pages-signs/b/brave.htm',
#  'BREAD': 'https://lifeprint.com/asl101//pages-signs/b/bread.htm',
#  'BREAK': 'https://lifeprint.com/asl101//pages-signs/b/break.htm',
#  'BREAK-UP': 'https://lifeprint.com/asl101//pages-signs/b/break-up.htm',
#  'BREAKFAST': 'https://lifeprint.com/asl101//pages-signs/b/breakfast.htm',
#  'BREASTFEED': 'https://lifeprint.com/asl101//pages-signs/b/breastfeed.htm',
#  'BREATHE': 'https://lifeprint.com/asl101//pages-signs/b/breathe.htm',
#  '\nBRIDESMAID': 'https://lifeprint.com/asl101//pages-signs/b/bridesmaid.htm',
#  'BRIDGE': 'https://lifeprint.com/asl101//pages-signs/b/bridge.htm',
#  'BRIGHT': 'https://lifeprint.com/asl101//pages-signs/b/bright.htm',
#  'BRING': 'https://lifeprint.com/asl101//pages-signs/b/bring.htm',
#  'BROKE': 'https://lifeprint.com/asl101//pages-signs/b/broke.htm',
#  '\nBRONCHIECTASIS': 'https://lifeprint.com/asl101//pages-signs/b/bronchiectasis.htm',
#  'BROTHER': 'https://lifeprint.com/asl101//pages-signs/b/brother.htm',
#  'BROWN': 'https://lifeprint.com/asl101//pages-signs/b/brown.htm',
#  'BRUISE': 'https://lifeprint.com/asl101//pages-signs/b/bruise.htm',
#  'BRUSH': 'https://lifeprint.com/asl101//pages-signs/b/brush.htm',
#  'BRUSH-TEETH': 'https://lifeprint.com/asl101//pages-signs/b/brushteeth.htm',
#  'BS': 'https://lifeprint.com/asl101//pages-signs/b/bs.htm',
#  'BUG': 'https://lifeprint.com/asl101//pages-signs/b/bug.htm',
#  'BUILD': 'https://lifeprint.com/asl101//pages-signs/b/build.htm',
#  'BUILDING': 'https://lifeprint.com/asl101//pages-signs/b/building.htm',
#  'BULLY': 'https://lifeprint.com/asl101//pages-signs/b/bully.htm',
#  'BUM': 'https://lifeprint.com/asl101//pages-signs/b/bum.htm',
#  'BUNK-BED': 'https://lifeprint.com/asl101//pages-signs/b/bunk-bed.htm',
#  'BURRITO': 'https://lifeprint.com/asl101//pages-signs/b/burrito.htm',
#  'BUS': 'https://lifeprint.com/asl101//pages-signs/b/bus.htm',
#  'BUSINESS': 'https://lifeprint.com/asl101//pages-signs/b/business.htm',
#  'BUSY-[#BUSY-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/b/busy.htm',
#  'BUT': 'https://lifeprint.com/asl101//pages-signs/b/but.htm',
#  'BUTTER': 'https://lifeprint.com/asl101//pages-signs/b/butter.htm',
#  'BUTTERFLY': 'https://lifeprint.com/asl101//pages-signs/b/butterfly.htm',
#  'BUTTON': 'https://lifeprint.com/asl101//pages-signs/b/button.htm',
#  'buy': 'https://lifeprint.com/asl101//pages-signs/b/buy.htm',
#  'BUZZ': 'https://lifeprint.com/asl101//pages-signs/b/buzz.htm',
#  'BY': 'https://lifeprint.com/asl101//pages-signs/b/by.htm',
#  'BY-A-HAIR': 'https://lifeprint.com/asl101//pages-signs/c/close-by-a-hair.htm',
#  'CABINET': 'https://lifeprint.com/asl101//pages-signs/c/cabinet.htm',
#  'CAFETERIA': 'https://lifeprint.com/asl101//pages-signs/c/cafeteria.htm',
#  'CAFFEINE': 'https://lifeprint.com/asl101//pages-signs/c/caffeine.htm',
#  'CAKE': 'https://lifeprint.com/asl101//pages-signs/c/cake.htm',
#  'CALIFORNIA': 'https://lifeprint.com/asl101//pages-signs/c/california.htm',
#  'CANADA': 'https://lifeprint.com/asl101//pages-signs/c/canada.htm',
#  'CALL': 'https://lifeprint.com/asl101//pages-signs/c/call.htm',
#  'calm-down-[see DOWN]': 'https://lifeprint.com/asl101//pages-signs/d/down.htm',
#  'CAMP': 'https://lifeprint.com/asl101//pages-signs/c/camp.htm',
#  'CAMPER': 'https://lifeprint.com/asl101//pages-signs/c/camper.htm',
#  'CAN': 'https://lifeprint.com/asl101//pages-signs/c/can.htm',
#  'can-(container)-[see CUP]': 'https://lifeprint.com/asl101//pages-signs/c/cup.htm',
#  'CANCEL': 'https://lifeprint.com/asl101//pages-signs/c/cancel.htm',
#  'CANCER': 'https://lifeprint.com/asl101//pages-signs/c/cancer.htm',
#  'candidate-[see APPLY]': 'https://lifeprint.com/asl101//pages-signs/a/apply.htm',
#  'CANDY': 'https://lifeprint.com/asl101//pages-signs/c/candy.htm',
#  'CAN’T': 'https://lifeprint.com/asl101//pages-signs/c/cant.htm',
#  'CAP': 'https://lifeprint.com/asl101//pages-signs/c/cap.htm',
#  'CAR': 'https://lifeprint.com/asl101//pages-signs/c/car.htm',
#  'CARD': 'https://lifeprint.com/asl101//pages-signs/c/card.htm',
#  'CARPOOL': 'https://lifeprint.com/asl101//pages-signs/c/carpool.htm',
#  'CARE': 'https://lifeprint.com/asl101//pages-signs/c/care.htm',
#  'CAREFUL': 'https://lifeprint.com/asl101//pages-signs/c/careful.htm',
#  'CARELESS': 'https://lifeprint.com/asl101//pages-signs/c/careless.htm',
#  'CARPENTER': 'https://lifeprint.com/asl101//pages-signs/c/carpenter.htm',
#  'CARIBOU': 'https://lifeprint.com/asl101//pages-signs/c/caribou.htm',
#  'CARTOON': 'https://lifeprint.com/asl101//pages-signs/c/cartoon.htm',
#  'CAT': 'https://lifeprint.com/asl101//pages-signs/c/cat.htm',
#  'CATEGORY': 'https://lifeprint.com/asl101//pages-signs/c/category.htm',
#  'CAUCASIAN': 'https://lifeprint.com/asl101//pages-signs/c/caucasian.htm',
#  'CAVE': 'https://lifeprint.com/asl101//pages-signs/c/cave.htm',
#  'CELEBRATE': 'https://lifeprint.com/asl101//pages-signs/c/celebrate.htm',
#  'CELL-PHONE': 'https://lifeprint.com/asl101//pages-signs/c/cellphone.htm',
#  'CEMETERY': 'https://lifeprint.com/asl101//pages-signs/c/cemetary.htm',
#  'CENTER': 'https://lifeprint.com/asl101//pages-signs/c/center.htm',
#  'CENTS': 'https://lifeprint.com/asl101//pages-signs/c/cents.htm',
#  'CENTURY': 'https://lifeprint.com/asl101//pages-signs/c/century.htm',
#  'CEREAL': 'https://lifeprint.com/asl101//pages-signs/c/cereal.htm',
#  'CHAIN': 'https://lifeprint.com/asl101//pages-signs/c/chain.htm',
#  'chair-[see SIT]': 'https://lifeprint.com/asl101//pages-signs/c/chair.htm',
#  'CHAMP or \nCHAMPION': 'https://lifeprint.com/asl101//pages-signs/c/champion.htm',
#  'CHANCE': 'https://lifeprint.com/asl101//pages-signs/c/chance.htm',
#  'CHANGE': 'https://lifeprint.com/asl101//pages-signs/c/change.htm',
#  'COINS': 'https://lifeprint.com/asl101//pages-signs/c/coins.htm',
#  'CHARACTER': 'https://lifeprint.com/asl101//pages-signs/c/character.htm',
#  'CHASE': 'https://lifeprint.com/asl101//pages-signs/c/chase.htm',
#  'CHAT': 'https://lifeprint.com/asl101//pages-signs/c/chat.htm',
#  'CHEAP': 'https://lifeprint.com/asl101//pages-signs/c/cheap.htm',
#  'CHEAT': 'https://lifeprint.com/asl101//pages-signs/c/cheat.htm',
#  'CHECK': 'https://lifeprint.com/asl101//pages-signs/c/check.htm',
#  'CHEESE': 'https://lifeprint.com/asl101//pages-signs/c/cheese.htm',
#  'CHESS': 'https://lifeprint.com/asl101//pages-signs/c/chess.htm',
#  'CHEW': 'https://lifeprint.com/asl101//pages-signs/c/chew.htm',
#  'CHICAGO': 'https://lifeprint.com/asl101//pages-signs/c/chicago.htm',
#  'CHICKEN': 'https://lifeprint.com/asl101//pages-signs/c/chicken.htm',
#  'CHICKEN_NUGGETS': 'https://lifeprint.com/asl101//pages-signs/c/chicken_nuggets.htm',
#  'CHILD': 'https://lifeprint.com/asl101//pages-signs/c/child.htm',
#  'CHIMNEY': 'https://lifeprint.com/asl101//pages-signs/c/chimney.htm',
#  'CHINA': 'https://lifeprint.com/asl101//pages-signs/c/china.htm',
#  'CHIPS': 'https://lifeprint.com/asl101//pages-signs/c/chips.htm',
#  'CHRIST': 'https://lifeprint.com/asl101//pages-signs/c/christ.htm',
#  'CHRISTMAS': 'https://lifeprint.com/asl101//pages-signs/c/christmas.htm',
#  'CHOCOLATE': 'https://lifeprint.com/asl101//pages-signs/c/chocolate.htm',
#  'CHRONIC': 'https://lifeprint.com/asl101//pages-signs/c/chronic.htm',
#  'CHURCH': 'https://lifeprint.com/asl101//pages-signs/c/church.htm',
#  'CIGARETTE': 'https://lifeprint.com/asl101//pages-signs/c/cigarette.htm',
#  'CITY': 'https://lifeprint.com/asl101//pages-signs/c/city.htm',
#  '\nCL:A': 'https://lifeprint.com/asl101//pages-signs/c/cla.htm',
#  'CL:1': 'https://lifeprint.com/asl101//pages-signs/c/cl1.htm',
#  'CL:3': 'https://lifeprint.com/asl101//pages-signs/c/cl3.htm',
#  'CL:4': 'https://lifeprint.com/asl101//pages-signs/c/cl4.htm',
#  '\nCL:5': 'https://lifeprint.com/asl101//pages-signs/c/cl5.htm',
#  'CL:B': 'https://lifeprint.com/asl101//pages-signs/c/clb.htm',
#  'CL:C': 'https://lifeprint.com/asl101//pages-signs/c/clc.htm',
#  '\nCL:G': 'https://lifeprint.com/asl101//pages-signs/c/clg.htm',
#  'CL:L': 'https://lifeprint.com/asl101//pages-signs/c/cll.htm',
#  'CL:R': 'https://lifeprint.com/asl101//pages-signs/c/clr.htm',
#  'CL:V': 'https://lifeprint.com/asl101//pages-signs/c/clv.htm',
#  'class-[see FAMILY]': 'https://lifeprint.com/asl101//pages-signs/f/family.htm',
#  'Classifiers': 'https://lifeprint.com/asl101//pages-signs/c/classifiers.htm',
#  'CLASS': 'https://lifeprint.com/asl101//pages-signs/c/class-group.htm',
#  'CLASSROOM': 'https://lifeprint.com/asl101//pages-signs/c/classroom.htm',
#  'CLEAN': 'https://lifeprint.com/asl101//pages-signs/c/clean.htm',
#  'Clean up your new cooking school papers before leaving.': 'https://lifeprint.com/asl101//pages-signs/c/clean-up-your-new-cooking-school-papers-before-leaving.htm',
#  'CLEAR': 'https://lifeprint.com/asl101//pages-signs/c/clear.htm',
#  'CLEVER': 'https://lifeprint.com/asl101//pages-signs/s/smart.htm',
#  'CLIMB': 'https://lifeprint.com/asl101//pages-signs/c/climb.htm',
#  'CLOCK': 'https://lifeprint.com/asl101//pages-signs/c/clock.htm',
#  'CLOSE': 'https://lifeprint.com/asl101//pages-signs/c/close-captioned.htm',
#  '\nCLOSE-THE-WINDOW': 'https://lifeprint.com/asl101//pages-signs/w/window-close.htm',
#  'CLOSET': 'https://lifeprint.com/asl101//pages-signs/c/closet.htm',
#  'CLOTHES': 'https://lifeprint.com/asl101//pages-signs/c/clothes.htm',
#  'CLOUD': 'https://lifeprint.com/asl101//pages-signs/c/cloud.htm',
#  '(S)': 'https://lifeprint.com/asl101//pages-signs/c/clouds.htm',
#  'CLOUDY': 'https://lifeprint.com/asl101//pages-signs/c/cloudy.htm',
#  'CLUB-[#CLUB-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/c/club.htm',
#  'CLUSTER': 'https://lifeprint.com/asl101//pages-signs/c/cluster.htm',
#  'COAT': 'https://lifeprint.com/asl101//pages-signs/c/coat.htm',
#  'COAT-animal': 'https://lifeprint.com/asl101//pages-signs/c/coat-animal.htm',
#  'COCHLEAR IMPLANT': 'https://lifeprint.com/asl101//pages-signs/c/coclear.htm',
#  'COFFEE': 'https://lifeprint.com/asl101//pages-signs/c/coffee.htm',
#  'COIN': 'https://lifeprint.com/asl101//pages-signs/c/coin.htm',
#  'CL:F': 'https://lifeprint.com/asl101//pages-signs/c/clf.htm',
#  'COKE': 'https://lifeprint.com/asl101//pages-signs/c/coke.htm',
#  'COLD': 'https://lifeprint.com/asl101//pages-signs/c/cold.htm',
#  'COLLECT': 'https://lifeprint.com/asl101//pages-signs/c/collect.htm',
#  'COLLEGE': 'https://lifeprint.com/asl101//pages-signs/c/college.htm',
#  'COLOR': 'https://lifeprint.com/asl101//pages-signs/c/color.htm',
#  'COLORADO': 'https://lifeprint.com/asl101//pages-signs/c/colorado.htm',
#  'COLORING': 'https://lifeprint.com/asl101//pages-signs/c/coloring.htm',
#  'COMB': 'https://lifeprint.com/asl101//pages-signs/c/comb.htm',
#  'COME': 'https://lifeprint.com/asl101//pages-signs/c/come.htm',
#  'COMMON SENSE': 'https://lifeprint.com/asl101//pages-signs/s/smart.htm',
#  'COMMUNICATION': 'https://lifeprint.com/asl101//pages-signs/c/communication.htm',
#  'COMMUTE': 'https://lifeprint.com/asl101//pages-signs/c/commute.htm',
#  'COMPLAIN': 'https://lifeprint.com/asl101//pages-signs/c/complain.htm',
#  '\nCOMPLIMENT': 'https://lifeprint.com/asl101//pages-signs/c/compliment.htm',
#  'COMPUTER': 'https://lifeprint.com/asl101//pages-signs/c/computer.htm',
#  'CONCLUDE': 'https://lifeprint.com/asl101//pages-signs/c/conclude.htm',
#  'CONFLICT': 'https://lifeprint.com/asl101//pages-signs/c/conflict.htm',
#  'CONGRATULATIONS': 'https://lifeprint.com/asl101//pages-signs/c/congratulations.htm',
#  'CONNECT': 'https://lifeprint.com/asl101//pages-signs/c/connect.htm',
#  'CONNECTICUT': 'https://lifeprint.com/asl101//pages-signs/c/connecticut.htm',
#  'CONSTRUCTION': 'https://lifeprint.com/asl101//pages-signs/b/build.htm',
#  'CONTAINER': 'https://lifeprint.com/asl101//pages-signs/c/container.htm',
#  '\nCONTENTION': 'https://lifeprint.com/asl101//pages-signs/c/contention.htm',
#  'CONTINENT': 'https://lifeprint.com/asl101//pages-signs/c/continent.htm',
#  '\nCONTINUE': 'https://lifeprint.com/asl101//pages-signs/c/continue.htm',
#  'CONVINCE': 'https://lifeprint.com/asl101//pages-signs/c/convince.htm',
#  'COOK': 'https://lifeprint.com/asl101//pages-signs/c/cook.htm',
#  'COOKIE': 'https://lifeprint.com/asl101//pages-signs/c/cookie.htm',
#  'COOL': 'https://lifeprint.com/asl101//pages-signs/c/cool2.htm',
#  'COPE': 'https://lifeprint.com/asl101//pages-signs/c/cope.htm',
#  'COPY': 'https://lifeprint.com/asl101//pages-signs/c/copy.htm',
#  'CORN': 'https://lifeprint.com/asl101//pages-signs/c/corn.htm',
#  'CORNER': 'https://lifeprint.com/asl101//pages-signs/c/corner.htm',
#  'CORRECT': 'https://lifeprint.com/asl101//pages-signs/c/correct.htm',
#  'COST': 'https://lifeprint.com/asl101//pages-signs/c/cost.htm',
#  'COUCH': 'https://lifeprint.com/asl101//pages-signs/c/couch.htm',
#  'COUGH': 'https://lifeprint.com/asl101//pages-signs/c/cough.htm',
#  'COUNSEL': 'https://lifeprint.com/asl101//pages-signs/c/counsel.htm',
#  'COUNT': 'https://lifeprint.com/asl101//pages-signs/c/count.htm',
#  'count-on': 'https://lifeprint.com/asl101//pages-signs/c/count-on.htm',
#  'COUNTRY': 'https://lifeprint.com/asl101//pages-signs/c/country.htm',
#  'COUNTRIES': 'https://lifeprint.com/asl101//pages-signs/c/countries.htm',
#  'court-[see IF]': 'https://lifeprint.com/asl101//pages-signs/i/if.htm',
#  'COUSIN': 'https://lifeprint.com/asl101//pages-signs/c/cousin.htm',
#  'COVER': 'https://lifeprint.com/asl101//pages-signs/c/cover.htm',
#  'COW': 'https://lifeprint.com/asl101//pages-signs/c/cow.htm',
#  'CRACK': 'https://lifeprint.com/asl101//pages-signs/c/crack.htm',
#  'CRASH': 'https://lifeprint.com/asl101//pages-signs/c/crash.htm',
#  'CRAZY': 'https://lifeprint.com/asl101//pages-signs/c/crazy.htm',
#  'CREATE': 'https://lifeprint.com/asl101//pages-signs/c/create.htm',
#  'CREATOR': 'https://lifeprint.com/asl101//pages-signs/c/creator.htm',
#  'CREDENTIAL': 'https://lifeprint.com/asl101//pages-signs/c/credential.htm',
#  'CRITICIZE': 'https://lifeprint.com/asl101//pages-signs/c/criticize.htm',
#  'CROCHET': 'https://lifeprint.com/asl101//pages-signs/c/crochet.htm',
#  'CROCODILE': 'https://lifeprint.com/asl101//pages-signs/a/alligator.htm',
#  'CROSSWALK': 'https://lifeprint.com/asl101//pages-signs/c/crosswalk.htm',
#  'CRUEL': 'https://lifeprint.com/asl101//pages-signs/c/cruel.htm',
#  'CRUSH': 'https://lifeprint.com/asl101//pages-signs/c/crush.htm',
#  'CRY': 'https://lifeprint.com/asl101//pages-signs/c/cry.htm',
#  'CULTURE': 'https://lifeprint.com/asl101//pages-signs/c/culture.htm',
#  'CUBBY': 'https://lifeprint.com/asl101//pages-signs/c/cubby.htm',
#  'CUPCAKE': 'https://lifeprint.com/asl101//pages-signs/c/cupcake.htm',
#  'CURLY': 'https://lifeprint.com/asl101//pages-signs/c/curley.htm',
#  'CURTAINS': 'https://lifeprint.com/asl101//pages-signs/c/curtains.htm',
#  'CUTE': 'https://lifeprint.com/asl101//pages-signs/c/cute.htm',
#  'Cut it \nout!': 'https://lifeprint.com/asl101//pages-signs/c/cut-it-out.htm',
#  'DAD': 'https://lifeprint.com/asl101//pages-signs/d/dad.htm',
#  'DAILY': 'https://lifeprint.com/asl101//pages-signs/e/everyday.htm',
#  'DAIRY': 'https://lifeprint.com/asl101//pages-signs/d/dairy.htm',
#  'DALLAS': 'https://lifeprint.com/asl101//pages-signs/d/dallas.htm',
#  'DANCE': 'https://lifeprint.com/asl101//pages-signs/d/dance.htm',
#  'DANCER': 'https://lifeprint.com/asl101//pages-signs/d/dancer.htm',
#  'DANDELION': 'https://lifeprint.com/asl101//pages-signs/d/dandelion.htm',
#  'DANGER': 'https://lifeprint.com/asl101//pages-signs/d/danger.htm',
#  'DARK': 'https://lifeprint.com/asl101//pages-signs/d/dark.htm',
#  'DATE': 'https://lifeprint.com/asl101//pages-signs/d/date.htm',
#  'daughter-[see BABY]': 'https://lifeprint.com/asl101//pages-signs/b/baby.htm',
#  'DAY': 'https://lifeprint.com/asl101//pages-signs/d/day.htm',
#  '\nDAYS OF THE WEEK': 'https://lifeprint.com/asl101//pages-signs/d/days-of-the-week.htm',
#  'DEAD': 'https://lifeprint.com/asl101//pages-signs/d/dead.htm',
#  'DEADLINE': 'https://lifeprint.com/asl101//pages-signs/d/deadline.htm',
#  'DEAF': 'https://lifeprint.com/asl101//pages-signs/d/deaf.htm',
#  'DEAFHOOD': 'https://lifeprint.com/asl101//pages-signs/d/deafhood.htm',
#  'DEAFNESS': 'https://lifeprint.com/asl101//pages-signs/d/deafness.htm',
#  'DEAF-SCHOOL': 'https://lifeprint.com/asl101//pages-signs/d/deaf_school.htm',
#  'DEAR': 'https://lifeprint.com/asl101//pages-signs/d/dear.htm',
#  'DECIDE': 'https://lifeprint.com/asl101//pages-signs/d/decide.htm',
#  'DECLINE': 'https://lifeprint.com/asl101//pages-signs/d/decline.htm',
#  'DECIMAL': 'https://lifeprint.com/asl101//pages-signs/d/decimal.htm',
#  'DECORATE': 'https://lifeprint.com/asl101//pages-signs/d/decorate.htm',
#  'DECREASE': 'https://lifeprint.com/asl101//pages-signs/d/decrease.htm',
#  'DEER': 'https://lifeprint.com/asl101//pages-signs/d/deer.htm',
#  'DEGREE': 'https://lifeprint.com/asl101//pages-signs/d/degree.htm',
#  '\nDEGREE-[educational]': 'https://lifeprint.com/asl101//pages-signs/d/degree-educational.htm',
#  'DELAWARE': 'https://lifeprint.com/asl101//pages-signs/d/delaware.htm',
#  'DELICIOUS': 'https://lifeprint.com/asl101//pages-signs/d/delicious.htm',
#  'DENTIST': 'https://lifeprint.com/asl101//pages-signs/d/dentist.htm',
#  'DENY': 'https://lifeprint.com/asl101//pages-signs/d/deny.htm',
#  'DEPEND': 'https://lifeprint.com/asl101//pages-signs/d/depend.htm',
#  'deplete-[see GONE]': 'https://lifeprint.com/asl101//pages-signs/g/gone.htm',
#  'DEPOSIT': 'https://lifeprint.com/asl101//pages-signs/d/deposit.htm',
#  'DEPRESSED': 'https://lifeprint.com/asl101//pages-signs/d/depressed.htm',
#  'DESSERT': 'https://lifeprint.com/asl101//pages-signs/d/dessert.htm',
#  'desk-[see TABLE]': 'https://lifeprint.com/asl101//pages-signs/t/table.htm',
#  'DESTROY': 'https://lifeprint.com/asl101//pages-signs/d/destroy.htm',
#  'DETECTIVE': 'https://lifeprint.com/asl101//pages-signs/d/detective.htm',
#  'DETROIT': 'https://lifeprint.com/asl101//pages-signs/d/detroit.htm',
#  'DEVELOP': 'https://lifeprint.com/asl101//pages-signs/d/develop.htm',
#  'diabetes': 'https://lifeprint.com/asl101//pages-signs/d/diabetes.htm',
#  'DIAPER': 'https://lifeprint.com/asl101//pages-signs/d/diaper.htm',
#  'dictionary': 'https://lifeprint.com/asl101//pages-signs/p/paper.htm',
#  "DIDN'T": 'https://lifeprint.com/asl101//pages-signs/d/didnt.htm',
#  'DIE': 'https://lifeprint.com/asl101//pages-signs/d/die.htm',
#  'DIET': 'https://lifeprint.com/asl101//pages-signs/d/diet.htm',
#  'DIFFERENT': 'https://lifeprint.com/asl101//pages-signs/d/different.htm',
#  'DIFFICULT': 'https://lifeprint.com/asl101//pages-signs/d/difficult.htm',
#  'DIG': 'https://lifeprint.com/asl101//pages-signs/d/dig.htm',
#  'DINING \nROOM': 'https://lifeprint.com/asl101//pages-signs/d/dining-room.htm',
#  'DINNER': 'https://lifeprint.com/asl101//pages-signs/d/dinner.htm',
#  'DINOSAUR': 'https://lifeprint.com/asl101//pages-signs/d/dinosaur.htm',
#  'DIPLOMA': 'https://lifeprint.com/asl101//pages-signs/d/diploma.htm',
#  'DIRT': 'https://lifeprint.com/asl101//pages-signs/d/dirt.htm',
#  'DIRTY': 'https://lifeprint.com/asl101//pages-signs/d/dirty.htm',
#  '\nDIRTY-MINDED': 'https://lifeprint.com/asl101//pages-signs/d/dirty-minded.htm',
#  'DISABLED': 'https://lifeprint.com/asl101//pages-signs/d/disabled.htm',
#  'DISAGREE-[see OPPOSITE]': 'https://lifeprint.com/asl101//pages-signs/o/opposite.htm',
#  'DISAPPEAR': 'https://lifeprint.com/asl101//pages-signs/d/disappear.htm',
#  'DISCOVER': 'https://lifeprint.com/asl101//pages-signs/f/find.htm',
#  'DISCUSS': 'https://lifeprint.com/asl101//pages-signs/d/discuss.htm',
#  'DISGUSTED': 'https://lifeprint.com/asl101//pages-signs/d/disgusted.htm',
#  'DISH': 'https://lifeprint.com/asl101//pages-signs/d/dish.htm',
#  '\nDISNEYLAND': 'https://lifeprint.com/asl101//pages-signs/d/disneyland.htm',
#  'DISPARAGE': 'https://lifeprint.com/asl101//pages-signs/d/disparage.htm',
#  'DISTANCE': 'https://lifeprint.com/asl101//pages-signs/d/distance.htm',
#  'DIVIDE': 'https://lifeprint.com/asl101//pages-signs/d/divide.htm',
#  'DIVORCE': 'https://lifeprint.com/asl101//pages-signs/d/divorce.htm',
#  'DIZZY': 'https://lifeprint.com/asl101//pages-signs/d/dizzy.htm',
#  'DO': 'https://lifeprint.com/asl101//pages-signs/d/do.htm',
#  'DO-what? \n[#DO-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/d/do-do.htm',
#  'DOCTOR': 'https://lifeprint.com/asl101//pages-signs/d/doctor.htm',
#  'DOG': 'https://lifeprint.com/asl101//pages-signs/d/dog.htm',
#  'DOLL': 'https://lifeprint.com/asl101//pages-signs/d/doll.htm',
#  'DOLLAR': 'https://lifeprint.com/asl101//pages-signs/d/dollar.htm',
#  'DOLPHIN': 'https://lifeprint.com/asl101//pages-signs/d/dolphin.htm',
#  '\nDONE-(FINISH)': 'https://lifeprint.com/asl101//pages-signs/f/finish.htm',
#  'DONKEY': 'https://lifeprint.com/asl101//pages-signs/d/donkey.htm',
#  "DON'T": 'https://lifeprint.com/asl101//pages-signs/d/dont.htm',
#  "\ndon't-CARE": 'https://lifeprint.com/asl101//pages-signs/d/dont-care.htm',
#  "\ndon't-FORGET": 'https://lifeprint.com/asl101//pages-signs/d/dont-forget.htm',
#  "don't-HAVE": 'https://lifeprint.com/asl101//pages-signs/d/dont-have.htm',
#  "don't-KNOW": 'https://lifeprint.com/asl101//pages-signs/d/dont-know.htm',
#  "don't-LIKE": 'https://lifeprint.com/asl101//pages-signs/d/dont-like.htm',
#  "don't-MIND": 'https://lifeprint.com/asl101//pages-signs/d/dontmind.htm',
#  "don't-WANT": 'https://lifeprint.com/asl101//pages-signs/d/dont-want.htm',
#  'DONUT': 'https://lifeprint.com/asl101//pages-signs/d/donut.htm',
#  'DOOR': 'https://lifeprint.com/asl101//pages-signs/d/door.htm',
#  'DORM': 'https://lifeprint.com/asl101//pages-signs/d/dorm.htm',
#  'DOTS': 'https://lifeprint.com/asl101//pages-signs/d/dots.htm',
#  'DOUGH': 'https://lifeprint.com/asl101//pages-signs/d/dough.htm',
#  'DOWN': 'https://lifeprint.com/asl101//pages-signs/d/down.htm',
#  'DOZEN\n': 'https://lifeprint.com/asl101//pages-signs/d/dozen.htm',
#  'Dr. PEPPER': 'https://lifeprint.com/asl101//pages-signs/d/drpepper.htm',
#  'DRAW': 'https://lifeprint.com/asl101//pages-signs/d/draw.htm',
#  'DRAWER': 'https://lifeprint.com/asl101//pages-signs/d/drawer.htm',
#  'DREAM': 'https://lifeprint.com/asl101//pages-signs/d/dream.htm',
#  'DRESS': 'https://lifeprint.com/asl101//pages-signs/d/dress.htm',
#  'DRESSER': 'https://lifeprint.com/asl101//pages-signs/d/dresser.htm',
#  '\nDRESSING ROOM': 'https://lifeprint.com/asl101//pages-signs/d/dressing-room.htm',
#  'DRIBBLE': 'https://lifeprint.com/asl101//pages-signs/d/dribble.htm',
#  'DRILL': 'https://lifeprint.com/asl101//pages-signs/d/drill.htm',
#  'DRINK': 'https://lifeprint.com/asl101//pages-signs/d/drink.htm',
#  'DRIVE': 'https://lifeprint.com/asl101//pages-signs/d/drive.htm',
#  'DROP': 'https://lifeprint.com/asl101//pages-signs/d/drop.htm',
#  'DRUNK': 'https://lifeprint.com/asl101//pages-signs/d/drunk.htm',
#  'DRYER': 'https://lifeprint.com/asl101//pages-signs/d/dryer.htm',
#  'DUCK': 'https://lifeprint.com/asl101//pages-signs/d/duck.htm',
#  'DUDE': 'https://lifeprint.com/asl101//pages-signs/d/dude.htm',
#  'dump': 'https://lifeprint.com/asl101//pages-signs/g/garbage.htm',
#  'DURING': 'https://lifeprint.com/asl101//pages-signs/d/during.htm',
#  'DUTY': 'https://lifeprint.com/asl101//pages-signs/d/duty.htm',
#  'DVD': 'https://lifeprint.com/asl101//pages-signs/d/dvd.htm',
#  'EACH': 'https://lifeprint.com/asl101//pages-signs/e/each.htm',
#  'EAGLE': 'https://lifeprint.com/asl101//pages-signs/e/eagle.htm',
#  'EARLY': 'https://lifeprint.com/asl101//pages-signs/e/early.htm',
#  'EARN': 'https://lifeprint.com/asl101//pages-signs/e/earn.htm',
#  'EARS': 'https://lifeprint.com/asl101//pages-signs/e/ears.htm',
#  'EARTH': 'https://lifeprint.com/asl101//pages-signs/e/earth.htm',
#  'EAST': 'https://lifeprint.com/asl101//pages-signs/e/east.htm',
#  'EASTER': 'https://lifeprint.com/asl101//pages-signs/e/easter.htm',
#  'EASY': 'https://lifeprint.com/asl101//pages-signs/e/easy.htm',
#  'EAT': 'https://lifeprint.com/asl101//pages-signs/e/eat.htm',
#  'EAT-YOUR-WORDS': 'https://lifeprint.com/asl101//pages-signs/e/eat-your-words.htm',
#  'EBOLA': 'https://lifeprint.com/asl101//pages-signs/e/ebola.htm',
#  'EGG': 'https://lifeprint.com/asl101//pages-signs/e/egg.htm',
#  'EITHER': 'https://lifeprint.com/asl101//pages-signs/e/either.htm',
#  'ELECTRICITY': 'https://lifeprint.com/asl101//pages-signs/e/electricity.htm',
#  'ELEPHANT': 'https://lifeprint.com/asl101//pages-signs/e/elephant.htm',
#  'ELEMENTARY': 'https://lifeprint.com/asl101//pages-signs/e/elementary.htm',
#  'ELEVATOR': 'https://lifeprint.com/asl101//pages-signs/e/elevator.htm',
#  'ELiS': 'https://lifeprint.com/asl101//elis/index.htm',
#  'ELOPE': 'https://lifeprint.com/asl101//pages-signs/e/elope.htm',
#  'EMAIL': 'https://lifeprint.com/asl101//pages-signs/e/email.htm',
#  'EMBARRASSED': 'https://lifeprint.com/asl101//pages-signs/e/embarrassed.htm',
#  'EMBASSY': 'https://lifeprint.com/asl101//pages-signs/e/embassy.htm',
#  'EMERGENCY': 'https://lifeprint.com/asl101//pages-signs/e/emergency.htm',
#  'EMOTION': 'https://lifeprint.com/asl101//pages-signs/e/emotion.htm',
#  'EMPTY': 'https://lifeprint.com/asl101//pages-signs/e/empty.htm',
#  'ENCORE': 'https://lifeprint.com/asl101//pages-signs/e/encore.htm',
#  'ENCOURAGE': 'https://lifeprint.com/asl101//pages-signs/e/encourage.htm',
#  'END': 'https://lifeprint.com/asl101//pages-signs/e/end.htm',
#  'ENGLAND': 'https://lifeprint.com/asl101//pages-signs/e/england.htm',
#  'ENGLISH': 'https://lifeprint.com/asl101//pages-signs/e/english.htm',
#  'ENJOY': 'https://lifeprint.com/asl101//pages-signs/e/enjoy.htm',
#  'ENOUGH': 'https://lifeprint.com/asl101//pages-signs/e/enough.htm',
#  'enter-[see IN]': 'https://lifeprint.com/asl101//pages-signs/i/in.htm',
#  'ENTHUSIASTIC': 'https://lifeprint.com/asl101//pages-signs/e/enthusiastic.htm',
#  '\nENVIRONMENT': 'https://lifeprint.com/asl101//pages-signs/e/environment.htm',
#  'EQUAL': 'https://lifeprint.com/asl101//pages-signs/e/equal.htm',
#  'ERASE': 'https://lifeprint.com/asl101//pages-signs/e/erase.htm',
#  'ESCAPE': 'https://lifeprint.com/asl101//pages-signs/e/escape.htm',
#  'ESTABLISH': 'https://lifeprint.com/asl101//pages-signs/e/establish.htm',
#  'ETCETERA': 'https://lifeprint.com/asl101//pages-signs/e/etcetera.htm',
#  'ETERNITY': 'https://lifeprint.com/asl101//pages-signs/a/always.htm',
#  'EURO': 'https://lifeprint.com/asl101//pages-signs/e/euro.htm',
#  'EUROPE': 'https://lifeprint.com/asl101//pages-signs/e/europe.htm',
#  '\nEVAPORATE': 'https://lifeprint.com/asl101//pages-signs/e/evaporate.htm',
#  'EVERY': 'https://lifeprint.com/asl101//pages-signs/e/every.htm',
#  'EVERYDAY': 'https://lifeprint.com/asl101//pages-signs/e/everyday.htm',
#  '\nEVERYWHERE': 'https://lifeprint.com/asl101//pages-signs/e/everywhere.htm',
#  'EXACT': 'https://lifeprint.com/asl101//pages-signs/e/exact.htm',
#  'EXAGGERATE': 'https://lifeprint.com/asl101//pages-signs/e/exaggerate.htm',
#  'EXAM': 'https://lifeprint.com/asl101//pages-signs/e/exam.htm',
#  'SHOW': 'https://lifeprint.com/asl101//pages-signs/s/show.htm',
#  'exchange-[see TRADE]': 'https://lifeprint.com/asl101//pages-signs/t/trade.htm',
#  'EXCITED': 'https://lifeprint.com/asl101//pages-signs/e/excited.htm',
#  'EXCUSE': 'https://lifeprint.com/asl101//pages-signs/e/excuse.htm',
#  'EXERCISE': 'https://lifeprint.com/asl101//pages-signs/e/exercise.htm',
#  'EXIT': 'https://lifeprint.com/asl101//pages-signs/e/exit.htm',
#  'EXPAND': 'https://lifeprint.com/asl101//pages-signs/e/expand.htm',
#  'EXPENSIVE': 'https://lifeprint.com/asl101//pages-signs/e/expensive.htm',
#  'EXPERIENCE': 'https://lifeprint.com/asl101//pages-signs/e/experience.htm',
#  'EXPERT': 'https://lifeprint.com/asl101//pages-signs/e/expert.htm',
#  'EXPIRE': 'https://lifeprint.com/asl101//pages-signs/e/expire.htm',
#  'EXPLAIN': 'https://lifeprint.com/asl101//pages-signs/e/explain.htm',
#  'EYES': 'https://lifeprint.com/asl101//pages-signs/e/eyes.htm',
#  'FACE': 'https://lifeprint.com/asl101//pages-signs/f/face.htm',
#  'FACEBOOK': 'https://lifeprint.com/asl101//pages-signs/f/facebook.htm',
#  'FACTORY': 'https://lifeprint.com/asl101//pages-signs/f/factory.htm',
#  'FAIL': 'https://lifeprint.com/asl101//pages-signs/f/fail.htm',
#  'FAIRY': 'https://lifeprint.com/asl101//pages-signs/f/fairy.htm',
#  'fall-[see AUTUMN, see CL:V]': 'https://lifeprint.com/asl101//pages-signs/c/clv.htm',
#  'FALL': 'https://lifeprint.com/asl101//pages-signs/f/fall.htm',
#  'FALL-FROM-GRACE': 'https://lifeprint.com/asl101//pages-signs/f/fall-from-grace.htm',
#  'FALSE': 'https://lifeprint.com/asl101//pages-signs/f/false.htm',
#  'FAMILIAR': 'https://lifeprint.com/asl101//pages-signs/f/familiar.htm',
#  'FAMILY': 'https://lifeprint.com/asl101//pages-signs/f/family.htm',
#  'FAMILY ROOM': 'https://lifeprint.com/asl101//pages-signs/f/family-room.htm',
#  'FANCY': 'https://lifeprint.com/asl101//pages-signs/f/fancy.htm',
#  'FAR': 'https://lifeprint.com/asl101//pages-signs/f/far.htm',
#  'FARM': 'https://lifeprint.com/asl101//pages-signs/f/farm.htm',
#  'FART': 'https://lifeprint.com/asl101//pages-signs/f/fart.htm',
#  'FAST': 'https://lifeprint.com/asl101//pages-signs/f/fast.htm',
#  'FAT': 'https://lifeprint.com/asl101//pages-signs/f/fat.htm',
#  'FATHER': 'https://lifeprint.com/asl101//pages-signs/d/dad.htm',
#  'FAULT': 'https://lifeprint.com/asl101//pages-signs/f/fault.htm',
#  'FAVORITE': 'https://lifeprint.com/asl101//pages-signs/f/favorite.htm',
#  'FEAR': 'https://lifeprint.com/asl101//pages-signs/f/fear.htm',
#  'FEATHER': 'https://lifeprint.com/asl101//pages-signs/f/feather.htm',
#  'FEDERAL': 'https://lifeprint.com/asl101//pages-signs/f/federal.htm',
#  'FEED': 'https://lifeprint.com/asl101//pages-signs/f/feed.htm',
#  'FEEL': 'https://lifeprint.com/asl101//pages-signs/f/feel.htm',
#  'FEET': 'https://lifeprint.com/asl101//pages-signs/f/feet.htm',
#  'FENCE': 'https://lifeprint.com/asl101//pages-signs/f/fence.htm',
#  'FERRET': 'https://lifeprint.com/asl101//pages-signs/f/ferret.htm',
#  'FEW': 'https://lifeprint.com/asl101//pages-signs/f/few.htm',
#  'FICTION': 'https://lifeprint.com/asl101//pages-signs/f/fiction.htm',
#  'FIELD': 'https://lifeprint.com/asl101//pages-signs/f/field.htm',
#  'FIGHT': 'https://lifeprint.com/asl101//pages-signs/f/fight.htm',
#  'figure-out': 'https://lifeprint.com/asl101//pages-signs/w/worse.htm',
#  'FILE': 'https://lifeprint.com/asl101//pages-signs/f/file.htm',
#  '\nFILLER-SIGNS': 'https://lifeprint.com/asl101//pages-signs/f/filler-signs.htm',
#  'FIND': 'https://lifeprint.com/asl101//pages-signs/f/find.htm',
#  'FINE': 'https://lifeprint.com/asl101//pages-signs/f/fine.htm',
#  'fingerspell': 'https://lifeprint.com/asl101//pages-signs/f/fingerspell.htm',
#  'Fingerspelling': 'https://lifeprint.com/asl101//fingerspelling/fingerspelling.htm',
#  'FINISH-(done)': 'https://lifeprint.com/asl101//pages-signs/f/finish.htm',
#  'FIRE': 'https://lifeprint.com/asl101//pages-signs/f/fire.htm',
#  'FIREMAN': 'https://lifeprint.com/asl101//pages-signs/f/fireman.htm',
#  '\nFIREFIGHTER': 'https://lifeprint.com/asl101//pages-signs/f/firefighter.htm',
#  'FIREFLY': 'https://lifeprint.com/asl101//pages-signs/f/firefly.htm',
#  'FIREWORKS': 'https://lifeprint.com/asl101//pages-signs/f/fireworks.htm',
#  'FIRST': 'https://lifeprint.com/asl101//pages-signs/f/first.htm',
#  'FISH': 'https://lifeprint.com/asl101//pages-signs/f/fish.htm',
#  'FISHERMAN': 'https://lifeprint.com/asl101//pages-signs/f/fisherman.htm',
#  'FIX': 'https://lifeprint.com/asl101//pages-signs/f/fix.htm',
#  'FLASH': 'https://lifeprint.com/asl101//pages-signs/f/flash.htm',
#  'FLAT': 'https://lifeprint.com/asl101//pages-signs/f/flat.htm',
#  'FLATTERY': 'https://lifeprint.com/asl101//pages-signs/f/flattery.htm',
#  'FLOOR': 'https://lifeprint.com/asl101//pages-signs/f/floor.htm',
#  'FLOPPY \nDISK': 'https://lifeprint.com/asl101//pages-signs/f/floppy_disk.htm',
# ...
#  'GRAY': 'https://lifeprint.com/asl101//pages-signs/g/gray.htm',
#  'GREAT': 'https://lifeprint.com/asl101//pages-signs/g/great.htm',
#  'GREEN': 'https://lifeprint.com/asl101//pages-signs/g/green.htm',
#  'GRITS': 'https://lifeprint.com/asl101//pages-signs/g/grits.htm',
#  'group-[see FAMILY]': 'https://lifeprint.com/asl101//pages-signs/f/family.htm',
#  'GROW': 'https://lifeprint.com/asl101//pages-signs/g/grow.htm',
#  'GUARDED': 'https://lifeprint.com/asl101//pages-signs/g/guarded.htm',
#  'GUEST': 'https://lifeprint.com/asl101//pages-signs/g/guest.htm',
#  '\nGUINEA-PIG': 'https://lifeprint.com/asl101//pages-signs/g/guinea-pig.htm',
#  'GYM': 'https://lifeprint.com/asl101//pages-signs/g/gym.htm',
#  '\nGYMNASTICS': 'https://lifeprint.com/asl101//pages-signs/g/gymnastics.htm',
#  'HABIT': 'https://lifeprint.com/asl101//pages-signs/h/habit.htm',
#  '\nHABIT-[religious-garment]': 'https://lifeprint.com/asl101//pages-signs/h/habit-religious-garment.htm',
#  'HAIR': 'https://lifeprint.com/asl101//pages-signs/h/hair.htm',
#  'HAIR-buzz': 'https://lifeprint.com/asl101//pages-signs/h/hair-buzz.htm',
#  'HAIRCUT': 'https://lifeprint.com/asl101//pages-signs/h/haircut.htm',
#  '\nHAIR-RAISING': 'https://lifeprint.com/asl101//pages-signs/h/hair-raising.htm',
#  'HALF': 'https://lifeprint.com/asl101//pages-signs/h/half.htm',
#  'HALF-HOUR': 'https://lifeprint.com/asl101//pages-signs/h/half-hour.htm',
#  'HALL': 'https://lifeprint.com/asl101//pages-signs/h/hall.htm',
#  'HALLOWEEN': 'https://lifeprint.com/asl101//pages-signs/h/halloween.htm',
#  'HAM': 'https://lifeprint.com/asl101//pages-signs/h/ham.htm',
#  'HAMBURGER': 'https://lifeprint.com/asl101//pages-signs/h/hamburger.htm',
#  'HAMMER': 'https://lifeprint.com/asl101//pages-signs/h/hammer.htm',
#  'HAND': 'https://lifeprint.com/asl101//pages-signs/h/hand.htm',
#  'HAND SANITIZER': 'https://lifeprint.com/asl101//pages-signs/h/hand-sanitizer.htm',
#  'HANDS': 'https://lifeprint.com/asl101//pages-signs/h/hands.htm',
#  '\nhandshapes': 'https://lifeprint.com/asl101//pages-layout/handshapes.htm',
#  'HANUKKAH': 'https://lifeprint.com/asl101//pages-signs/h/hanukkah.htm',
#  'HAPPEN': 'https://lifeprint.com/asl101//pages-signs/h/happen.htm',
#  'HAPPY': 'https://lifeprint.com/asl101//pages-signs/h/happy.htm',
#  'HARD': 'https://lifeprint.com/asl101//pages-signs/h/hard.htm',
#  'HARD-OF-HEARING': 'https://lifeprint.com/asl101//pages-signs/h/hard-of-hearing.htm',
#  'HAT': 'https://lifeprint.com/asl101//pages-signs/h/hat.htm',
#  'HAUNTED-HOUSE': 'https://lifeprint.com/asl101//pages-signs/h/haunted-house.htm',
#  'HAVE': 'https://lifeprint.com/asl101//pages-signs/h/have.htm',
#  'NEED': 'https://lifeprint.com/asl101//pages-signs/n/need.htm',
#  'HAWAII': 'https://lifeprint.com/asl101//pages-signs/h/hawaii.htm',
#  'HE': 'https://lifeprint.com/asl101//pages-signs/h/he.htm',
#  'HEAD': 'https://lifeprint.com/asl101//pages-signs/h/headcold.htm',
#  '\nHEADPHONES': 'https://lifeprint.com/asl101//pages-signs/h/headphones.htm',
#  'HEAL / \nHEALTHY': 'https://lifeprint.com/asl101//pages-signs/b/brave.htm',
#  'health-[see BODY]': 'https://lifeprint.com/asl101//pages-signs/b/body.htm',
#  'HEAR': 'https://lifeprint.com/asl101//pages-signs/h/hear.htm',
#  'HEARING': 'https://lifeprint.com/asl101//pages-signs/h/hearing.htm',
#  'HEARING-AID': 'https://lifeprint.com/asl101//pages-signs/h/hearing-aid.htm',
#  '\nHEARING-IMPAIRED (not recommended)': 'https://lifeprint.com/asl101//pages-signs/h/hearing-impaired.htm',
#  'HEART': 'https://lifeprint.com/asl101//pages-signs/h/heart.htm',
#  'HEAVY': 'https://lifeprint.com/asl101//pages-signs/h/heavy.htm',
#  'Helen \nKeller': 'https://lifeprint.com/asl101//pages-signs/h/helen-keller.htm',
#  'HELICOPTER': 'https://lifeprint.com/asl101//pages-signs/h/helicopter.htm',
#  'HELLO': 'https://lifeprint.com/asl101//pages-signs/h/hello.htm',
#  'HELP': 'https://lifeprint.com/asl101//pages-signs/h/help.htm',
#  'HERE': 'https://lifeprint.com/asl101//pages-signs/h/here.htm',
#  'HERMIT': 'https://lifeprint.com/asl101//pages-signs/h/hermit.htm',
#  'HEY': 'https://lifeprint.com/asl101//pages-signs/h/hey.htm',
#  'HIDE': 'https://lifeprint.com/asl101//pages-signs/h/hide.htm',
#  'HIGH': 'https://lifeprint.com/asl101//pages-signs/h/high.htm',
#  '\nHIGH-SCHOOL': 'https://lifeprint.com/asl101//pages-signs/h/high-school.htm',
#  'cl:v': 'https://lifeprint.com/asl101//pages-signs/c/clv.htm',
#  'HIPPIE': 'https://lifeprint.com/asl101//pages-signs/h/hippie.htm',
#  'HIPPOPOTAMUS': 'https://lifeprint.com/asl101//pages-signs/h/hippopotamus.htm',
#  'HIRE': 'https://lifeprint.com/asl101//pages-signs/h/hire.htm',
#  'possession': 'https://lifeprint.com/asl101//pages-signs/p/possession.htm',
#  'HISTORY': 'https://lifeprint.com/asl101//pages-signs/h/history.htm',
#  'HIT': 'https://lifeprint.com/asl101//pages-signs/h/hit.htm',
#  'HOCKEY': 'https://lifeprint.com/asl101//pages-signs/h/hockey.htm',
#  'Holiday': 'https://lifeprint.com/asl101//pages-signs/h/holiday.htm',
#  'HOLLAND': 'https://lifeprint.com/asl101//pages-signs/h/holland.htm',
#  'Holocaust': 'https://lifeprint.com/asl101//pages-signs/h/holocaust.htm',
#  'HOME': 'https://lifeprint.com/asl101//pages-signs/h/home.htm',
#  'HOMEWORK': 'https://lifeprint.com/asl101//pages-signs/h/homework.htm',
#  'HONEY-I-SHRUNK-THE-AUDIENCE': 'https://lifeprint.com/asl101//pages-signs/h/honey-i-shrunk-the-audience.htm',
#  'HONOR': 'https://lifeprint.com/asl101//pages-signs/h/honor.htm',
#  'HORSE': 'https://lifeprint.com/asl101//pages-signs/h/horse.htm',
#  'HOSPICE': 'https://lifeprint.com/asl101//pages-signs/h/hospice.htm',
#  'HOSPITAL': 'https://lifeprint.com/asl101//pages-signs/h/hospital.htm',
#  'HOT': 'https://lifeprint.com/asl101//pages-signs/h/hot.htm',
#  'HOT-AIR-BALLOON': 'https://lifeprint.com/asl101//pages-signs/h/hot-air-balloon.htm',
#  'HOTEL': 'https://lifeprint.com/asl101//pages-signs/h/hotel.htm',
#  'HOTDOG': 'https://lifeprint.com/asl101//pages-signs/h/hotdog.htm',
#  'HOUR': 'https://lifeprint.com/asl101//pages-signs/h/hour.htm',
#  '1/2-HOUR': 'https://lifeprint.com/asl101//pages-signs/h/hour.htm',
#  'HOUSE': 'https://lifeprint.com/asl101//pages-signs/h/house.htm',
#  'HOUSEHOLD': 'https://lifeprint.com/asl101//pages-signs/h/household.htm',
#  'HOUSTON': 'https://lifeprint.com/asl101//pages-signs/h/houston.htm',
#  'HOW': 'https://lifeprint.com/asl101//pages-signs/h/how.htm',
#  'HOW-ARE-YOU?': 'https://lifeprint.com/asl101//pages-signs/h/how-are-you.htm',
#  'HOW-MUCH': 'https://lifeprint.com/asl101//pages-signs/h/how-much.htm',
#  'HOW-MANY': 'https://lifeprint.com/asl101//pages-signs/h/how-many.htm',
#  'How was your day?': 'https://lifeprint.com/asl101//pages-signs/h/how-was-your-day.htm',
#  'HUG': 'https://lifeprint.com/asl101//pages-signs/h/hug.htm',
#  'HUH?': 'https://lifeprint.com/asl101//pages-signs/h/huh.htm',
#  'HUMBLE': 'https://lifeprint.com/asl101//pages-signs/h/humble.htm',
#  'HUMMINGBIRD': 'https://lifeprint.com/asl101//pages-signs/h/hummingbird.htm',
#  'HUMP': 'https://lifeprint.com/asl101//pages-signs/h/hump.htm',
#  'HUNGRY': 'https://lifeprint.com/asl101//pages-signs/h/hungry.htm',
#  'HURRY': 'https://lifeprint.com/asl101//pages-signs/h/hurry.htm',
#  'HURT': 'https://lifeprint.com/asl101//pages-signs/h/hurt.htm',
#  'HUSH': 'https://lifeprint.com/asl101//pages-signs/h/hush.htm',
#  'husband-[see MARRIAGE]': 'https://lifeprint.com/asl101//pages-signs/m/marriage.htm',
#  'I or "me"': 'https://lifeprint.com/asl101//pages-signs/i/i.htm',
#  '"I am"': 'https://lifeprint.com/asl101//pages-signs/i/i-am.htm',
#  'I-Pad': 'https://lifeprint.com/asl101//pages-signs/i/ipad.htm',
#  'ICE-[#ICE-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/i/ice.htm',
#  'ICE': 'https://lifeprint.com/asl101//pages-signs/i/icecream.htm',
#  'ice-skate-[see ROLLER-BLADE]': 'https://lifeprint.com/asl101//pages-signs/r/roller-blade.htm',
#  'IDAHO': 'https://lifeprint.com/asl101//pages-signs/i/idaho.htm',
#  'IDEA': 'https://lifeprint.com/asl101//pages-signs/i/idea.htm',
#  'IF-[#IF-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/i/if.htm',
#  'ILLINOIS': 'https://lifeprint.com/asl101//pages-signs/i/illinois.htm',
#  'IMMIGRANT': 'https://lifeprint.com/asl101//pages-signs/i/immigrant.htm',
#  'IMMIGRATION': 'https://lifeprint.com/asl101//pages-signs/i/immigration.htm',
#  'IMPORTANT': 'https://lifeprint.com/asl101//pages-signs/i/important.htm',
#  'IMPOSSIBLE': 'https://lifeprint.com/asl101//pages-signs/i/impossible.htm',
#  'IMPRESSED': 'https://lifeprint.com/asl101//pages-signs/i/impressed.htm',
#  'IMPROVE': 'https://lifeprint.com/asl101//pages-signs/i/improve.htm',
#  'IN': 'https://lifeprint.com/asl101//pages-signs/i/in.htm',
#  'INCH': 'https://lifeprint.com/asl101//pages-signs/i/inch.htm',
#  'INCOMPETENT': 'https://lifeprint.com/asl101//pages-signs/i/incompetent.htm',
#  'INCREASE': 'https://lifeprint.com/asl101//pages-signs/i/increase.htm',
#  'Indexing': 'https://lifeprint.com/asl101//pages-signs/i/indexing.htm',
#  'INDIA': 'https://lifeprint.com/asl101//pages-signs/i/india.htm',
#  'INDIAN': 'https://lifeprint.com/asl101//pages-signs/i/indian.htm',
#  'INDIANA': 'https://lifeprint.com/asl101//pages-signs/i/indiana.htm',
#  'INFECTION': 'https://lifeprint.com/asl101//pages-signs/i/infection.htm',
#  'INHERIT': 'https://lifeprint.com/asl101//pages-signs/i/inherit.htm',
#  'INK': 'https://lifeprint.com/asl101//pages-signs/i/ink.htm',
#  'IN-LAW': 'https://lifeprint.com/asl101//pages-signs/i/in-law.htm',
#  'INNOCENT': 'https://lifeprint.com/asl101//pages-signs/i/innocent.htm',
#  'INSPIRE': 'https://lifeprint.com/asl101//pages-signs/i/inspire.htm',
#  'INSTITUTE': 'https://lifeprint.com/asl101//pages-signs/i/institute.htm',
#  'INSTRUMENT': 'https://lifeprint.com/asl101//pages-signs/i/instrument.htm',
#  'INSULT': 'https://lifeprint.com/asl101//pages-signs/i/insult.htm',
#  'INTEREST': 'https://lifeprint.com/asl101//pages-signs/i/interest.htm',
#  'INTERESTING': 'https://lifeprint.com/asl101//pages-signs/i/interesting.htm',
#  'INTERMINABLE': 'https://lifeprint.com/asl101//pages-signs/i/interminable.htm',
#  'INTERNET': 'https://lifeprint.com/asl101//pages-signs/i/internet.htm',
#  'INTERPRETER': 'https://lifeprint.com/asl101//pages-signs/i/interpreter.htm',
#  'INTERRUPT': 'https://lifeprint.com/asl101//pages-signs/i/interrupt.htm',
#  'INTERSECT': 'https://lifeprint.com/asl101//pages-signs/i/intersect.htm',
#  'intersection/crossroads-[see CONFLICT \npage]': 'https://lifeprint.com/asl101//pages-signs/c/conflict.htm',
#  'INTERSECTION': 'https://lifeprint.com/asl101//pages-signs/i/intersection.htm',
#  'INTERVIEW': 'https://lifeprint.com/asl101//pages-signs/i/interview.htm',
#  'INTRUDE': 'https://lifeprint.com/asl101//pages-signs/i/intrude.htm',
#  'INVENT': 'https://lifeprint.com/asl101//pages-signs/i/invent.htm',
#  'INVEST': 'https://lifeprint.com/asl101//pages-signs/i/invest.htm',
#  'INVESTIGATE': 'https://lifeprint.com/asl101//pages-signs/i/investigate.htm',
#  'INVISIBLE': 'https://lifeprint.com/asl101//pages-signs/i/invisible.htm',
#  'INVOLVED': 'https://lifeprint.com/asl101//pages-signs/i/involved.htm',
#  'IRELAND': 'https://lifeprint.com/asl101//pages-signs/i/ireland.htm',
#  'is-[How to handle "be verbs"]': 'https://lifeprint.com/asl101//pages-signs/b/be-verbs.htm',
#  'ish (-ish)': 'https://lifeprint.com/asl101//pages-signs/i/-ish.htm',
#  'ISLAND': 'https://lifeprint.com/asl101//pages-signs/i/island.htm',
#  'ISRAEL': 'https://lifeprint.com/asl101//pages-signs/i/israel.htm',
#  'ISSUES': 'https://lifeprint.com/asl101//pages-signs/i/issues.htm',
#  'IT': 'https://lifeprint.com/asl101//pages-signs/i/it.htm',
#  'ITALY': 'https://lifeprint.com/asl101//pages-signs/i/italy.htm',
#  'ITCH': 'https://lifeprint.com/asl101//pages-signs/i/itch.htm',
#  'JACKET': 'https://lifeprint.com/asl101//pages-signs/j/jacket.htm',
#  'JAIL': 'https://lifeprint.com/asl101//pages-signs/j/jail.htm',
#  'JANITOR': 'https://lifeprint.com/asl101//pages-signs/j/janitor.htm',
#  'JAPAN': 'https://lifeprint.com/asl101//pages-signs/j/japan.htm',
#  'JEALOUS': 'https://lifeprint.com/asl101//pages-signs/j/jealous.htm',
#  "JEHOVAH'S WITNESSES": 'https://lifeprint.com/asl101//pages-signs/j/jehovahs_witnesses.htm',
#  'JESUS': 'https://lifeprint.com/asl101//pages-signs/j/jesus.htm',
#  'JEWISH': 'https://lifeprint.com/asl101//pages-signs/j/jewish.htm',
#  'JOB-[#JOB-(lexicalized)]': 'https://lifeprint.com/asl101//pages-signs/j/job.htm',
#  'JOIN': 'https://lifeprint.com/asl101//pages-signs/j/join.htm',
#  'JOKE': 'https://lifeprint.com/asl101//pages-signs/j/joke.htm',
#  'joking': 'https://lifeprint.com/asl101//pages-signs/t/tease.htm',
#  'judge-[see IF]': 'https://lifeprint.com/asl101//pages-signs/i/if.htm',
#  'JUICE': 'https://lifeprint.com/asl101//pages-signs/j/juice.htm',
#  'JUMP': 'https://lifeprint.com/asl101//pages-signs/j/jump.htm',
#  'JUNIOR': 'https://lifeprint.com/asl101//pages-signs/j/junior.htm',
#  'JUST': 'https://lifeprint.com/asl101//pages-signs/j/just.htm',
#  'KEEP': 'https://lifeprint.com/asl101//pages-signs/k/keep.htm',
#  'KETCHUP': 'https://lifeprint.com/asl101//pages-signs/k/ketchup.htm',
#  'KEYBOARD': 'https://lifeprint.com/asl101//pages-signs/k/keyboard.htm',
#  'KEYS': 'https://lifeprint.com/asl101//pages-signs/k/key.htm',
#  'KILL': 'https://lifeprint.com/asl101//pages-signs/k/kill.htm',
#  'KISS': 'https://lifeprint.com/asl101//pages-signs/k/kiss.htm',
#  'KITCHEN': 'https://lifeprint.com/asl101//pages-signs/k/kitchen.htm',
#  'KITE': 'https://lifeprint.com/asl101//pages-signs/k/kite.htm',
#  'KITTEN': 'https://lifeprint.com/asl101//pages-signs/k/kitten.htm',
#  'KNIFE': 'https://lifeprint.com/asl101//pages-signs/k/knife.htm',
#  'KNIT': 'https://lifeprint.com/asl101//pages-signs/k/knit.htm',
#  'KNOW': 'https://lifeprint.com/asl101//pages-signs/k/know.htm',
#  'KOALA': 'https://lifeprint.com/asl101//pages-signs/k/koala.htm',
#  'KOREA': 'https://lifeprint.com/asl101//pages-signs/k/korea.htm',
#  'KWANZAA': 'https://lifeprint.com/asl101//pages-signs/k/kwanzaa.htm',
#  'LA-LA-LA': 'https://lifeprint.com/asl101//pages-signs/l/la-la-la.htm',
#  'LAB': 'https://lifeprint.com/asl101//pages-signs/l/lab.htm',
#  'LABOR-DAY': 'https://lifeprint.com/asl101//pages-signs/l/laborday.htm',
#  'LADY': 'https://lifeprint.com/asl101//pages-signs/l/lady.htm',
#  'big': 'https://lifeprint.com/asl101//pages-signs/b/big.htm',
#  'LAID-OUT': 'https://lifeprint.com/asl101//pages-signs/l/laid-out.htm',
#  'LAME': 'https://lifeprint.com/asl101//pages-signs/l/lame.htm',
#  'LANGUAGE': 'https://lifeprint.com/asl101//pages-signs/l/language.htm',
#  'LAST': 'https://lifeprint.com/asl101//pages-signs/l/last.htm',
#  'LATE': 'https://lifeprint.com/asl101//pages-signs/l/late.htm',
#  'LATER': 'https://lifeprint.com/asl101//pages-signs/l/later.htm',
#  'LAUGH': 'https://lifeprint.com/asl101//pages-signs/l/laugh.htm',
#  'LAUNDRY': 'https://lifeprint.com/asl101//pages-signs/l/laundry.htm',
#  'LAUNDRY ROOM': 'https://lifeprint.com/asl101//pages-signs/l/laundry-room.htm',
#  'LAW': 'https://lifeprint.com/asl101//pages-signs/l/law.htm',
#  'LAWYER': 'https://lifeprint.com/asl101//pages-signs/l/lawyer.htm',
#  'LAY': 'https://lifeprint.com/asl101//pages-signs/l/lay.htm',
#  'LAYER': 'https://lifeprint.com/asl101//pages-signs/l/layer.htm',
#  'LAZY': 'https://lifeprint.com/asl101//pages-signs/l/lazy.htm',
#  'LEARN': 'https://lifeprint.com/asl101//pages-signs/l/learn.htm',
#  'LEAP': 'https://lifeprint.com/asl101//pages-signs/l/leap.htm',
#  'LEAVE': 'https://lifeprint.com/asl101//pages-signs/l/leave.htm',
#  'ABANDON': 'https://lifeprint.com/asl101//pages-signs/a/abandon.htm',
#  'LEBANON': 'https://lifeprint.com/asl101//pages-signs/l/lebanon.htm',
#  'LECTURE': 'https://lifeprint.com/asl101//pages-signs/l/lecture.htm',
#  'LEFT': 'https://lifeprint.com/asl101//pages-signs/l/left.htm',
#  'LEG': 'https://lifeprint.com/asl101//pages-signs/l/leg.htm',
#  'LEMON': 'https://lifeprint.com/asl101//pages-signs/l/lemon.htm',
#  'LESBIAN': 'https://lifeprint.com/asl101//pages-signs/l/lesbian.htm',
#  'LESSON': 'https://lifeprint.com/asl101//pages-signs/l/lesson.htm',
#  'LETTER': 'https://lifeprint.com/asl101//pages-signs/l/letter.htm',
#  'Lexicalized ': 'https://lifeprint.com/asl101//pages-signs/l/lexicalized%20.htm',
#  'LIBRARY': 'https://lifeprint.com/asl101//pages-signs/l/library.htm',
#  ...}

# %%
pickle.dump(entire_dict, open('cached_dict', 'wb'))

# %%
post_random_content(entire_dict, creds, content_type = 'youtube')
# Out:
# YouTube embedded video posted to Reddit
# location      https://www.youtube.com/embed/I3lZvG43Z14?rel=0
# name                                                      POP
# text        POP / "soda pop"Form the left hand into an "O....
# type                                                  youtube
# Name: 0, dtype: object

# %% [markdown]
# # Exploration

# %%
url = 'https://www.lifeprint.com/asl101/pages-signs/p/pineapple.htm'

page = requests.get(url)
soup_temp = BeautifulSoup(page.content, "html.parser")

# %%
videos = soup_temp.find_all('iframe')
video = videos[0]
get_description(video)
# Out:
# 'ASL: "pineapple"The sign for "pineapple"\xa0has a many versions.PINEAPPLE:\xa0 S and modified-L version:'

# %%
isinstance(my_temp, type('bs4.element.NavigableString'))
# Out:
# False

# %%
my_temp = video.previous.previous.previous.previous.previous.previous.previous.previous.previous.previous.previous.previous.previous.previous.name
my_temp
# Out:
# 'font'

# %%
soup_temp
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html><head>
# <title>ASL pineapple</title>
# <meta content="ASL,pineapple,American Sign Language,Sign Language,learn sign language,Deaf,signing,what is the sign for,how do you sign" name="keywords"/>
# <meta content='ASL pineapple. What is the sign for "pineapple" in American Sign Language (ASL)?' name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en-us" http-equiv="Content-Language"/>
# <meta content="William Vicars" name="author"/>
# <meta content="index,follow" name="robots"/>
# <meta content="Global" name="distribution"/>
# <meta content="30 days" name="revisit-after"/>
# <meta content="Copyright William Vicars / Lifeprint.com" name="copyright"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">A {text-decoration: none} a:hover{color:#000033; background-color: yellow} p {margin-top:0px; margin-bottom:0px; font-family: Arial, Helvetica, sans-serif;} margin-right: 0</style>
# </head>
# <body bgcolor="#FFFFFF" face="Arial" font="" hspace="0" marginwidth="0" topmargin="0">
# <body bgcolor="#FFFFFF" face="Arial" font="" hspace="0" marginwidth="0" rightmargin="0" style="margin-top: 0; margin-bottom: 0" topmargin="0">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 728x90-leaderboard -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-2513564923850231" data-ad-slot="7543121294" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <hr align="left" color="#000000" size="1"/>
# <p align="right">
# <a href="../../lessons/lessons.htm">ASL Lessons</a> |
# <a href="../../../bookstore/bookstore.htm">Bookstore </a>|
# <a href="../../pages-layout/topics.htm">Library</a> |<a href="../../../index.htm" style="text-decoration: none" target="_top"> ASL University
# Main ►</a></p></body></body></html>
# <hr align="left" color="#000000" size="1" width="100%"/>
# <div style="display:block;float:right;margin: 5px 20px 5px 5px;">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- ASL (American Sign Language) 160 x 600 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-2513564923850231" data-ad-slot="4979558599" style="display:inline-block;width:160px;height:600px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <blockquote>
# <h1 style="margin-top: 0; margin-bottom: 0">
# <font face="Arial">
# <span style="font-weight: 400"><font size="5">ASL: "pineapple"</font></span><br/>
# </font></h1>
# <p><br/>
# 	The sign for "pineapple" has a many versions.<br/>
# <br/>
# PINEAPPLE:  S and modified-L version:<br/>
# <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/1gTTOfSNYvI" width="560"></iframe><br/>
# https://youtu.be/1gTTOfSNYvI<hr/>
# <p><br/>
# PINEAPPLE: Chiquita advertising campaign version:<br/>
# <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/1x7E5RakWdg" width="560"></iframe><br/>
# https://youtu.be/1x7E5RakWdg</p>
# <p> </p>
# <hr/>
# <p><br/>
# PINEAPPLE: Initialized "apple" version:<br/>
# <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/PjiwR-MDl_4" width="560"></iframe><br/>
# https://youtu.be/PjiwR-MDl_4<br/>
#  </p>
# <hr/>
# <p> </p>
# <p>PINEAPPLE: "chop chop" version:<br/>
# <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/q84Rcj-lR3A" width="560"></iframe><br/>
# <img border="0" height="320" src="../../signjpegs/p/pineapple-v4-01-.jpg" width="320"/><img border="0" height="320" src="../../signjpegs/p/pineapple-v4-02-.jpg" width="320"/></p>
# <hr/>
# <p><br/>
# For many years
# 	I used to recommend the "F" hand near the "eye" version
# which was shown to me (years ago) by a fellow from Hawaii. Apparently it is based on the
# 	"fruit hat" made popular by the Chiquita advertising campaign.
# These days I've "stopped" recommending any particular version of "pineapple" and
# instead recommend you use whatever version your local native Deaf adult signers
# use.  Actually that is good advice for "any" sign these days. I try to show
# the most popular versions of every sign and any reasonably common variations --
# but you should always sign in the way your local Deaf sign. When in Rome do as
# the Romans do is a cliche and still around for a reason -- it is still true
# after all these years.<br/>
# <br/>
# 	Hold the "F" hand in front of your eye (as if looking through the hole in
# 	the "F") and twist it twice (as if adjusting a telescope).<br/>
# <br/>
# 	PINEAPPLE: <br/>
# <img border="0" height="300" src="../../signjpegs/p/pineapple-1.jpg" width="300"/><img border="0" height="300" src="../../signjpegs/p/pineapple-2.jpg" width="300"/><img border="0" height="300" src="../../signjpegs/p/pineapple-3.jpg" width="300"/><br/>
#  <hr align="left" color="#000000" size="1" width="25%"/>
# <p style="margin-top: 0; margin-bottom: 0">
# 	PINEAPPLE (animated)<br/>
# <img border="0" height="360" longdesc="The ASL sign for pineapple." src="../../gifs-animated/pineapple.gif" width="360"/><img border="0" src="../../signjpegs/p/pineap7.jpg"/><p style="margin-top: 0; margin-bottom: 0">
# 	 <hr align="left" color="#000000" size="1"/>
# <p style="margin-top: 0; margin-bottom: 0"><br/>
# 	Another version of "pineapple" is to use a "P" (a "K" actually) on the
# 	cheek.  Twist it twice.<br/>
# <br/>
# 	PINEAPPLE (initialized version)<br/>
# <img border="0" src="../../signjpegs/p/pineapple-4.jpg"/><img border="0" src="../../signjpegs/p/pineapple-5.jpg"/><img border="0" src="../../signjpegs/p/pineapple-6.jpg"/></p>
# <p style="margin-top: 0; margin-bottom: 0">
# 	 <hr align="left" color="#000000" size="1" width="25%"/>
# <p style="margin-top: 0; margin-bottom: 0">
# 	PINEAPPLE (initialized version) (animated)<br/>
# <img border="0" height="300" longdesc="The ASL sign for pineapple." src="../../gifs-animated/pineapple-2.gif" width="300"/><p style="margin-top: 0; margin-bottom: 0"> </p>
# <hr align="left" color="#000000" size="1"/>
# <p style="margin-top: 0; margin-bottom: 0"><br/>
# 	Notes:<br/>
# 	In a message dated 11/14/2011 4:18:36 P.M. Pacific Standard Time, Jamie
# 	Saunders writes:<br/>
# <br/>
# 	Hi Dr. Vicars, <br/>
# 	I really enjoyed showing your dictionary to my teachers and students a lot
# 	and I am profoundly deaf/ native ASL signer myself. I noticed there is a
# 	word needed to add to your dictionary: PINEAPPLE.. Can you please add and
# 	thought a bit more about contrasting with PICKLE?  My co-workers
# 	(kindergarten teacher who is hearing ) and I debate what is right sign for
# 	"pickle" and "pineapple." I have searched all online and PICKLE/PINEAPPLE
# 	are similar in signs. I know you are very busy man and we would love to hear
# 	back from you one day when you are free. <br/>
# 	Much Thanks! <br/>
# 	~Jamie Saunders<br/>
# <br/>
# 	Jamie,<br/>
# 	Hello :)<br/>
# 	Well, for <b>many years</b> I did the sign PINEAPPLE using the tip of the
# 	middle finger of a "K" handshape on my cheek.  I differentiated the
# 	sign PINEAPPLE from sign with PICKLE by doing the sign PICKLE near the
# 	corner of my chin. <br/>
# 	Then one day a friend who has spent some time in Hawaii showed me her sign
# 	for PINEAPPLE using an "F" hand in front of her eye and explained to me that
# 	it had to do with the "fruit hat" like the one worn by the "Chiquita Lady"
# 	(in the advertisements by the Chiquita company that sells bananas and
# 	related items).<br/>
# 	Since the "F"-hand version of the sign PINEAPPLE is very iconic (the
# 	extended fingers look like the leaves of a pineapple plant) and it has ties
# 	to a cultural aspect of the usage of a pineapple (being with other fruit in
# 	a fruit basket carried on the head) I was instantly smitten with the
# 	appropriateness of the sign and I highly recommend it to you as my preferred
# 	version.<br/>
# 	Cordially,<br/>
# 	-- Dr. Bill<br/>
#  </p>
# <hr align="left" color="#000000" size="1"/>
# <p style="margin-top: 0; margin-bottom: 0">See: <a href="pickle.htm">PICKLE</a></p>
# <hr align="left" color="#000000" size="1"/>
# <p>
#  <hr align="left" color="#000000" size="1"/>
# <script type="text/javascript"><!--
# google_ad_client = "ca-pub-2513564923850231";
# /* 728x15_link_ads_adsense1_bottom */
# google_ad_slot = "2289748297";
# google_ad_width = 728;
# google_ad_height = 15;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# <p align="center" style="margin-top: 0; margin-bottom: 0"></p>
# <script type="text/javascript"><!--
# google_ad_client = "ca-pub-2513564923850231";
# /* 728x15_link_ads_adsense1_bottom */
# google_ad_slot = "2289748297";
# google_ad_width = 728;
# google_ad_height = 15;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# <p align="center" style="margin-top: 0; margin-bottom: 0"></p>
# <script type="text/javascript"><!--
# google_ad_client = "ca-pub-2513564923850231";
# /* 728x15_link_ads_adsense1_bottom */
# google_ad_slot = "2289748297";
# google_ad_width = 728;
# google_ad_height = 15;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script>
# <hr align="left" color="#000000" size="1"/>
#
#  <p>Notes:<br/>
#
# One of my colleagues (while eating ham and pineapple pizza!) showed me a
# horizontal non-dominant S with a straight-fingered claw hand sticking up -- I
# thought it was brilliant in terms of quickly demonstrating the shape of a
# pineapple. Very iconic.</p>
# <p style="margin-top: 0; margin-bottom: 0"> </p>
# <hr align="left" color="#000000" size="1"/>
# </p>
# <hr align="left" color="#000000" size="1"/>
# <p style="margin-top: 0; margin-bottom: 0"><br/>
# *
# Want to help support ASL University?  It's <i>easy</i>: </p></p></p></p></p></p></p></blockquote><b>
# <a href="https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&amp;hosted_button_id=XHRNABERKJT4N" rel="nofollow" target="_blank">
# <u>DONATE</u></a></b><font size="2">  (<i>Thanks!</i>)</font><br/>
# <br/>
# <font face="Arial">
# 		*  </font>Another way to help is to buy something from Dr. Bill's "<b><a href="../../../bookstore/bookstore.htm"><u>Bookstore</u></a></b>."
# <p style="margin-top: 0; margin-bottom: 0">
# <br/>
# <font face="Arial">
# 		*  </font>Want even more ASL resources?  Visit the "<b><a href="http://www.asl.tc/landing/index.html" rel="nofollow" target="_blank">ASL Training Center</a>!</b>"  (Subscription
# Extension of ASLU)   <br/>
# <br/>
# </p>*  Also check out Dr. Bill's channel:
# 		<a href="http://www.youtube.com/billvicars">www.youtube.com/billvicars</a>
# <font size="2"> <br/>
#  </font>
# <hr align="left" color="#000000" size="1"/>
# <p align="center" style="margin-top: 0; margin-bottom: 0">
# <font size="1">You can learn <a href="http://lifeprint.com">American Sign Language (ASL)</a> online at American Sign Language University ™
# 		<br/>
# <a href="http://asl.ms" style="text-decoration: none">ASL</a> resources by Lifeprint.com  ©  Dr. William Vicars  </font> </p>
# <hr color="#000000" size="1"/>
#
# <p></p>
#
# <div style="display:block;float:right;margin: 5px 5px 5px 20px;">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 336x280 bottom of page ASL American Sign Language -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-2513564923850231" data-ad-slot="6501232513" style="display:inline-block;width:336px;height:280px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <!-- Comments can go here. ASL or American Sign Language-->

# %%
page_letter_a = parse_dictionary_main_page("https://lifeprint.com/asl101/index/a.htm")
main_page
# Out:
# {'@': 'https://lifeprint.com/asl101//pages-signs/a/at.htm',
#  "ABC's": 'https://lifeprint.com/asl101//pages-signs/a/abcs.htm',
#  'ABBREVIATE': 'https://lifeprint.com/asl101//pages-signs/a/abbreviate.htm',
#  'ABORTION': 'https://lifeprint.com/asl101//pages-signs/a/abortion.htm',
#  'ABOUT': 'https://lifeprint.com/asl101//pages-signs/a/about.htm',
#  'ABOVE': 'https://lifeprint.com/asl101//pages-signs/a/above.htm',
#  'ABUSE': 'https://lifeprint.com/asl101//pages-signs/a/abuse.htm',
#  'ACADEMIC': 'https://lifeprint.com/asl101//pages-signs/a/academic.htm',
#  'ACCEPT': 'https://lifeprint.com/asl101//pages-signs/a/accept.htm',
#  'ACCENT': 'https://lifeprint.com/asl101//pages-signs/a/accent.htm',
#  'ACCIDENT': 'https://lifeprint.com/asl101//pages-signs/a/accident.htm',
#  'accompany-[see WITH]': 'https://lifeprint.com/asl101//pages-signs/w/with.htm',
#  'ACCOMPLICE': 'https://lifeprint.com/asl101//pages-signs/a/accomplice.ht.htm',
#  'ACCOMPLISH': 'https://lifeprint.com/asl101//pages-signs/a/accomplish.htm',
#  'ACCOUNTANT': 'https://lifeprint.com/asl101//pages-signs/c/count.htm',
#  'ACQUAINTANCE': 'https://lifeprint.com/asl101//pages-signs/a/acquaintance.htm',
#  'ACQUIRE': 'https://lifeprint.com/asl101//pages-signs/a/acquire.htm',
#  'ACROSS': 'https://lifeprint.com/asl101//pages-signs/a/across.htm',
#  'ACT': 'https://lifeprint.com/asl101//pages-signs/a/act.htm',
#  'ACTIVE': 'https://lifeprint.com/asl101//pages-signs/a/active.htm',
#  'ACTOR': 'https://lifeprint.com/asl101//pages-signs/a/actor.htm',
#  'ACTUALLY': 'https://lifeprint.com/asl101//pages-signs/a/actually.htm',
#  'ADD': 'https://lifeprint.com/asl101//pages-signs/a/add.htm',
#  'ADDICT': 'https://lifeprint.com/asl101//pages-signs/a/addict.htm',
#  'add-to': 'https://lifeprint.com/asl101//pages-signs/a/all-together.htm',
#  'ADDRESS': 'https://lifeprint.com/asl101//pages-signs/a/address.htm',
#  'administration-[see MANAGER]': 'https://lifeprint.com/asl101//pages-signs/m/manager.htm',
#  'adopt-[see TAKE-UP]': 'https://lifeprint.com/asl101//pages-signs/t/take-up.htm',
#  'ADOPT': 'https://lifeprint.com/asl101//pages-signs/a/adopt.htm',
#  'ADULT': 'https://lifeprint.com/asl101//pages-signs/a/adult.htm',
#  'advise/advice-[see COUNSEL]': 'https://lifeprint.com/asl101//pages-signs/c/counsel.htm',
#  'AFRAID': 'https://lifeprint.com/asl101//pages-signs/a/afraid.htm',
#  'AFRICA': 'https://lifeprint.com/asl101//pages-signs/a/africa.htm',
#  'AFTER': 'https://lifeprint.com/asl101//pages-signs/a/after.htm',
#  'AFTERNOON': 'https://lifeprint.com/asl101//pages-signs/a/afternoon.htm',
#  'AGAIN': 'https://lifeprint.com/asl101//pages-signs/a/again.htm',
#  'AGAINST': 'https://lifeprint.com/asl101//pages-signs/a/against.htm',
#  'AGENT': 'https://lifeprint.com/asl101//pages-signs/a/agent.htm',
#  'AGGRESSIVE': 'https://lifeprint.com/asl101//pages-signs/a/aggressive.htm',
#  'AGREE': 'https://lifeprint.com/asl101//pages-signs/a/agree.htm',
#  'AIDE': 'https://lifeprint.com/asl101//pages-signs/a/aide.htm',
#  'AIR': 'https://lifeprint.com/asl101//pages-signs/a/air.htm',
#  'AIR CONDITIONING': 'https://lifeprint.com/asl101//pages-signs/a/air-conditioning.htm',
#  'AIRPLANE': 'https://lifeprint.com/asl101//pages-signs/a/airplane.htm',
#  'ALABAMA': 'https://lifeprint.com/asl101//pages-signs/a/alabama.htm',
#  'ALASKA': 'https://lifeprint.com/asl101//pages-signs/a/alaska.htm',
#  'ALCOHOL': 'https://lifeprint.com/asl101//pages-signs/a/alcohol.htm',
#  'ALCOHOLIC': 'https://lifeprint.com/asl101//pages-signs/a/alcoholic.htm',
#  'allergy': 'https://lifeprint.com/asl101//pages-signs/o/opposite.htm',
#  'ALL': 'https://lifeprint.com/asl101//pages-signs/a/all.htm',
#  'ALLIGATOR': 'https://lifeprint.com/asl101//pages-signs/a/alligator.htm',
#  'all-over/-dom-[see FIELD]': 'https://lifeprint.com/asl101//pages-signs/f/field.htm',
#  'ALLOW': 'https://lifeprint.com/asl101//pages-signs/a/allow.htm',
#  'almost-[see EASY]': 'https://lifeprint.com/asl101//pages-signs/a/almost.htm',
#  'alone-[see SINGLE]': 'https://lifeprint.com/asl101//pages-signs/s/single.htm',
#  'A-LOT': 'https://lifeprint.com/asl101//pages-signs/a/a-lot.htm',
#  'ALMOST': 'https://lifeprint.com/asl101//pages-signs/a/almost.htm',
#  'ALOHA': 'https://lifeprint.com/asl101//pages-signs/a/aloha.htm',
#  'ALPHABET': 'https://lifeprint.com/asl101//pages-signs/a/alphabet.htm',
#  'ALRIGHT': 'https://lifeprint.com/asl101//pages-signs/a/alright.htm',
#  'ALSO': 'https://lifeprint.com/asl101//pages-signs/a/also.htm',
#  'ALTOGETHER': 'https://lifeprint.com/asl101//pages-signs/a/altogether.htm',
#  'ALWAYS': 'https://lifeprint.com/asl101//pages-signs/a/always.htm',
#  'AM': 'https://lifeprint.com/asl101//pages-signs/a/am.htm',
#  'ambulance-[see LIGHT]': 'https://lifeprint.com/asl101//pages-signs/l/light.htm',
#  'AMERICA': 'https://lifeprint.com/asl101//pages-signs/a/america.htm',
#  'American': 'https://lifeprint.com/asl101//pages-signs/a/american.htm',
#  'American: Native American': 'https://lifeprint.com/asl101//pages-signs/a/american-indian.htm',
#  'Amish': 'https://lifeprint.com/asl101//pages-signs/a/amish.htm',
#  'AMOUNT': 'https://lifeprint.com/asl101//pages-signs/a/amount.htm',
#  'an': 'https://lifeprint.com/asl101//pages-signs/a/an.htm',
#  'AND': 'https://lifeprint.com/asl101//pages-signs/a/and.htm',
#  'ANGEL': 'https://lifeprint.com/asl101//pages-signs/a/angel.htm',
#  'ANGRY': 'https://lifeprint.com/asl101//pages-signs/a/angry.htm',
#  'ANIMAL': 'https://lifeprint.com/asl101//pages-signs/a/animal.htm',
#  'ANIMALS': 'https://lifeprint.com/asl101//pages-signs/a/animals.htm',
#  'annually': 'https://lifeprint.com/asl101//pages-signs/y/yearadvanced.htm',
#  'ANSWER': 'https://lifeprint.com/asl101//pages-signs/a/answer.htm',
#  'ANT': 'https://lifeprint.com/asl101//pages-signs/a/ant.htm',
#  'ANTHROPOLOGY': 'https://lifeprint.com/asl101//pages-signs/a/anthropology.htm',
#  'ANY': 'https://lifeprint.com/asl101//pages-signs/a/any.htm',
#  'ANXIOUS': 'https://lifeprint.com/asl101//pages-signs/a/anxious.htm',
#  'APARTMENT': 'https://lifeprint.com/asl101//pages-signs/a/apartment.htm',
#  'APE': 'https://lifeprint.com/asl101//pages-signs/a/ape.htm',
#  'APOSTROPHE': 'https://lifeprint.com/asl101//pages-signs/a/apostrophe.htm',
#  'APOSTROPHE S': 'https://lifeprint.com/asl101//pages-signs/a/apostrophe-s.htm',
#  'APPEAR': 'https://lifeprint.com/asl101//pages-signs/a/appear.htm',
#  'APPLAUSE': 'https://lifeprint.com/asl101//pages-signs/a/applause.htm',
#  'APPLE': 'https://lifeprint.com/asl101//pages-signs/a/apple.htm',
#  'APPLY': 'https://lifeprint.com/asl101//pages-signs/a/apply.htm',
#  'APPOINTMENT': 'https://lifeprint.com/asl101//pages-signs/a/appointment.htm',
#  'APPRECIATE': 'https://lifeprint.com/asl101//pages-signs/e/enjoy.htm',
#  'APPROXIMATELY': 'https://lifeprint.com/asl101//pages-signs/a/approximately.htm',
#  'ARE': 'https://lifeprint.com/asl101//pages-signs/a/are.htm',
#  'AREA': 'https://lifeprint.com/asl101//pages-signs/a/area.htm',
#  'ARGUE': 'https://lifeprint.com/asl101//pages-signs/a/argue.htm',
#  'ARIZONA': 'https://lifeprint.com/asl101//pages-signs/a/arizona.htm',
#  'ARKANSAS': 'https://lifeprint.com/asl101//pages-signs/a/arkansas.htm',
#  'ARMY': 'https://lifeprint.com/asl101//pages-signs/a/army.htm',
#  '\naround-[see APPROXIMATELY]': 'https://lifeprint.com/asl101//pages-signs/a/approximately.htm',
#  'ARRIVE': 'https://lifeprint.com/asl101//pages-signs/a/arrive.htm',
#  'art-[see DRAW]': 'https://lifeprint.com/asl101//pages-signs/d/draw.htm',
#  'ARTHRITIS': 'https://lifeprint.com/asl101//pages-signs/a/arthritis.htm',
#  '\narticle/column-[see CL:C]': 'https://lifeprint.com/asl101//pages-signs/c/clc.htm',
#  'ARTICLE': 'https://lifeprint.com/asl101//pages-signs/a/article.htm',
#  'ASK': 'https://lifeprint.com/asl101//pages-signs/a/ask.htm',
#  'ASSAULT': 'https://lifeprint.com/asl101//pages-signs/a/assault.htm',
#  '\nASSIGNMENT': 'https://lifeprint.com/asl101//pages-signs/a/assignment.htm',
#  'ASSOCIATE': 'https://lifeprint.com/asl101//pages-signs/a/associate.htm',
#  'ASSOCIATION': 'https://lifeprint.com/asl101//pages-signs/a/association.htm',
#  'ASTERISK': 'https://lifeprint.com/asl101//pages-signs/a/asterisk.htm',
#  '\nAT': 'https://lifeprint.com/asl101//pages-signs/a/at.htm',
#  'ATM': 'https://lifeprint.com/asl101//pages-signs/a/atm.htm',
#  'ATLANTA': 'https://lifeprint.com/asl101//pages-signs/a/atlanta.htm',
#  'ATTENTION': 'https://lifeprint.com/asl101//pages-signs/a/attention.htm',
#  'AUDIENCE': 'https://lifeprint.com/asl101//pages-signs/a/audience.htm',
#  'AUNT': 'https://lifeprint.com/asl101//pages-signs/a/aunt.htm',
#  'AUSTRALIA': 'https://lifeprint.com/asl101//pages-signs/a/australia.htm',
#  'AUTISM': 'https://lifeprint.com/asl101//pages-signs/a/autism.htm',
#  'AUTUMN': 'https://lifeprint.com/asl101//pages-signs/a/autumn.htm',
#  'AVERAGE': 'https://lifeprint.com/asl101//pages-signs/a/average.htm',
#  'AVOCADO': 'https://lifeprint.com/asl101//pages-signs/a/avocado.htm',
#  '\nAWAY': 'https://lifeprint.com/asl101//pages-signs/a/away.htm',
#  'AWESOME': 'https://lifeprint.com/asl101//pages-signs/a/awesome.htm',
#  'AWFUL': 'https://lifeprint.com/asl101//pages-signs/a/awful.htm',
#  'AWKWARD': 'https://lifeprint.com/asl101//pages-signs/a/awkward.htm'}

# %%
# https://www.lifeprint.com/asl101/pages-signs/a/at.htm
soup2 = pickle.load(open('soup2', 'rb'))

# %%
videos = soup2.find_all('iframe')
videos
# Out:
# [<iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/1hDXCyZm1vA?rel=0&amp;autoplay=1" width="560"></iframe>]

# %%
images = soup2.find_all('img')
images
# Out:
# [<img border="0" src="../../signjpegs/a/at.htm5.jpg"/>,
#  <img border="0" height="219" src="../../signjpegs/a/at1.jpg" width="245"/>,
#  <img border="0" height="219" src="../../signjpegs/a/at2.jpg" width="245"/>]

# %%
video = videos[0]

# %%
get_description(video)
# Out:
# 'AT: To do the sign for "at" as in the symbol @ that is commonly used in email addresses use an "A" handshape and circle it in the air as if drawing the symbol:@ '

# %%
for video in videos:
    name = name
    type = 'video'
    text = ''.join([res.text for res in videos[0].fetchPreviousSiblings()])
    location = video['src']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-e8b46b1c3ae0> in <module>
#       1 for video in videos:
# ----> 2     name = name
#       3     type = 'video'
#       4     text = ''.join([res.text for res in videos[0].fetchPreviousSiblings()])
#       5     location = video['src']
#
# NameError: name 'name' is not defined

# %%
''.join([res.text for res in videos[0].fetchPreviousSiblings()])
# Out:
# '@'

# %%
soup2
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
#
# <html>
# <head>
# <title>"at" American Sign Language (ASL)</title>
# <meta content="The sign for at in American Sign Language (ASL)." name="description"/>
# <meta content="at,American Sign Language,Sign Language,ASL,learn ASL,Deaf,signing" name="keywords"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <style type="text/css">A {text-decoration: none} a:hover{color:#000033; background-color: yellow}</style>
# </head>
# <body bgcolor="#FFFFFF" rightmargin="0" topmargin="0"><font face="Arial">
# <font face="Arial">
# <p align="right" style="margin-top: 0; margin-bottom: 0"> <a href="../../../index.htm" style="text-decoration: none" target="_top">ASL
# University ►</a></p>
# <hr color="#000000" size="6" style="border-style: ridge; border-width: 2; padding-left: 0; padding-right: 0; padding-top: 1; padding-bottom: 1"/>
# <table border="0" id="table1" width="100%">
# <tr>
# <td align="left" valign="top">
# <font size="5">American Sign Language:  "at"</font><br/>
# <blockquote>
# <hr align="left" color="#000000" size="1" width="50%"/>
# <p style="margin-top: 0; margin-bottom: 0">AT:
# 	<br/>
# 	To do the sign for "at" as in the symbol @ that is commonly used in email
# 	addresses use an "A" handshape and circle it in the air as if drawing the
# 	symbol:<br/>
# <font size="6">@</font> <br/>
# <br/>
# <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="315" src="https://www.youtube.com/embed/1hDXCyZm1vA?rel=0&amp;autoplay=1" width="560"></iframe><br/>
# 	It really isn't an issue if you do the movement clockwise or
# 	counterclockwise.<br/>
# 	I've yet to see a consensus on that. But in general it is standard to draw
# 	and show things from your own perspective, so that is the way I do it.<br/>
# <img border="0" src="../../signjpegs/a/at.htm5.jpg"/><br/>
#  <hr color="#000000"/>
# <font face="Arial">
# <hr color="#000000"/>
# </font> <p><font color="#FF0000" size="4">Warning!</font>  This next
# 	version is <i>rarely</i> used in ASL.  <br/>
#   	It is NOT used in phrases like "at least."
#   <br/>
# <br/>
# 	Instead of signing "AT" in "<b>at</b> least you can" you would sign
# 	something like, "YOU STILL CAN ..." or "MINIMUM (version)."<br/>
# <br/>
# 	Instead of signing "<b>at</b> last" you would sign "<a href="../s/succeed.htm" style="text-decoration: none">pah</a>"
# 	(finally).<br/>
# <br/>
#
#   	Instead of signing "We will meet <b>at</b> my home tomorrow," you would
# 	sign, TOMORROW MEET MY HOME. <br/>
# <br/>
# 	Instead of signing "Where <b>at</b>?"  You would just sign "WHERE?" and
# 	use an appropriate question facial expression.<br/>
# <br/>
# 	I'm showing the version below not so you will use it, but rather so you can
# 	<i>recognize</i> it if you see it.  </p>
# <p>AT:<br/>
# <img border="0" height="219" src="../../signjpegs/a/at1.jpg" width="245"/><img border="0" height="219" src="../../signjpegs/a/at2.jpg" width="245"/></p>
# <hr align="left" color="#000000" size="1" width="50%"/>
# <p style="margin-top: 0; margin-bottom: 0"> </p>
# </p></blockquote>
# <!--webbot bot="Include" U-Include="../../topics/adsense1.htm" TAG="BODY" startspan -->
# <hr/>
# <form action="http://www.google.com/cse" id="cse-search-box" target="_blank">
# <div>
# <input name="cx" type="hidden" value="partner-pub-2513564923850231:nzof3qz9abm"/>
# <input name="ie" type="hidden" value="ISO-8859-1"/>
# <p align="right" style="margin-top: 0; margin-bottom: 0">
# <input name="q" size="31" type="text"/>
# <input name="sa" type="submit" value="Search"/> </p></div>
# </form>
# <p style="margin-top: 0; margin-bottom: 0"><font size="2">Want to help support
# ASL University?  It's <i>easy</i>:
# </font><b>
# <a href="https://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&amp;hosted_button_id=XHRNABERKJT4N" rel="nofollow" target="_blank">
# <u>DONATE</u></a></b><font size="2"> (<i>Thanks!</i>)</font><br/>
# <font size="2">(You don't need a PayPal account. Just look for the credit card
# logos and click continue.)<br/>
# <br/>
# Another way to help is to buy something from the ASLU "<a href="../../../bookstore/bookstore.htm">Bookstore</a>."<br/>
# <br/>
# Want even more ASL resources?  Visit the "<b>ASL Training Center!</b>"  (Subscription
# Extension of ASLU)
# <a href="http://www.asl.tc/landing/index.html" rel="nofollow" target="_blank">
# <u>CHECK IT OUT</u> &gt;</a> </font></p>
# <p style="margin-top: 0; margin-bottom: 0">
# <br/>
# <font size="2">Bandwidth slow?  Check out "ASLUniversity.com" (a
# free <i>mirror</i> of
# Lifeprint.com less traffic, fast access)
# <a href="http://asluniversity.com" rel="nofollow" target="_blank"><u>VISIT</u> &gt;</a>
# </font></p>
# <p style="margin-top: 0; margin-bottom: 0"> </p>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 728x90-leaderboard -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-2513564923850231" data-ad-slot="7543121294" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/>
# <!--webbot bot="Include" i-checksum="30181" endspan --><p align="center" style="margin-top: 0; margin-bottom: 0">
# <font face="Arial" size="1">You can learn
# <a href="http://www.lifeprint.com" style="text-decoration: none">
# sign language</a> (ASL) online at American Sign Language University ™<br/>
# Lifeprint.com  ©  Dr. William Vicars</font></p>
# </td></tr></table></font> </font></body></html>
# <td align="right" valign="top" width="160">
# <!--webbot bot="Include" U-Include="../../topics/adsense2.htm" TAG="BODY" startspan -->
# <!--webbot bot="Include" i-checksum="96" endspan --></td>
#
#
# <p align="left" style="margin-top: 0; margin-bottom: 0"></p>
# <p style="margin-top: 0; margin-bottom: 0"> </p>
